# %%
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision.transforms import v2
from progressBar import printProgressBar

import medicalDataLoader
import argparse
import utils

from UNet_Base import *
import random
import torch
import pdb
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Define hyperparameters
batch_size = 8
batch_size_val = 4
lr =  0.01   # Learning Rate
total_epochs = 120  # Number of epochs
weight_decay = 1e-5

# %%
# Define image and mask transformations
transform = v2.Compose([
    v2.ToTensor(),
    v2.Normalize(mean=[0.137], std=[0.1733])
])

mask_transform = v2.Compose([
    v2.ToTensor(),
])

# %%
# Define dataloaders
root_dir = './data/'
print(' Dataset: {} '.format(root_dir))

train_set_full = medicalDataLoader.MedicalImageDataset('train',
                                                    root_dir,
                                                    transform=transform,
                                                    mask_transform=mask_transform,
                                                    augment=True,
                                                    equalize=False)

train_loader_full = DataLoader(train_set_full,
                            batch_size=batch_size,
                            worker_init_fn=np.random.seed(0),
                            num_workers=0,
                            shuffle=True)


val_set = medicalDataLoader.MedicalImageDataset('val',
                                                root_dir,
                                                transform=transform,
                                                mask_transform=mask_transform,
                                                equalize=False)

val_loader = DataLoader(val_set,
                        batch_size=batch_size_val,
                        worker_init_fn=np.random.seed(0),
                        num_workers=0,
                        shuffle=False)
# Out:
#  Dataset: ./data/

# %% [markdown]
# Note: Calculating the mean and std only has to be done once and this cell is only for reference. Hence, the parameters do not have to be adapted!

# %%
"""Calculate Mean and Std of the dataset"""
# Initialize variables to store the sum and sum of squares of pixel values
mean = 0.0
std = 0.0
nb_samples = 0

for data in train_loader_full:
    images, _, _ = data
    batch_samples = images.size(0)  # batch size (the last batch can have smaller size)
    images = images.view(batch_samples, images.size(1), -1)
    mean += images.mean(2).sum(0)
    std += images.std(2).sum(0)
    nb_samples += batch_samples

mean /= nb_samples
std /= nb_samples

print(f'Mean: {mean}')
print(f'Std: {std}')
# Out:
# Mean: tensor([0.0034])
# Std: tensor([1.0004])

# %%
for i, sample in enumerate(train_loader_full):
    images, masks, _ = sample
    print('Image batch dimensions: ', images.size())
    print('Mask batch dimensions: ', masks.size())
    
    # Show first image and mask
    plt.figure()
    plt.subplot(1,2,1)
    plt.imshow(images[0,0,:,:], cmap='gray')
    plt.title('Image')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(masks[0,0,:,:], cmap='gray')
    plt.title('Mask')
    plt.axis('off')
    plt.show()

    print(utils.getTargetSegmentation(masks[0,0,:,:]).shape)

    break
# Out:
# Image batch dimensions:  torch.Size([8, 1, 256, 256])
# Mask batch dimensions:  torch.Size([8, 1, 256, 256])
# torch.Size([256, 256])

# %%
def runTraining(writer: SummaryWriter):
    print("-" * 40)
    print("~~~~~~~~  Starting the training... ~~~~~~")
    print("-" * 40)

    num_classes = 4

    # Set device depending on the availability of GPU
    if torch.cuda.is_available():
        device = torch.device("cuda")
    elif torch.mps.is_available():  # Apple M-series of chips
        device = torch.device("mps")
    else:
        device = torch.device("cpu")

    print(f"Using device: {device}")

    print("~~~~~~~~~~~ Creating the UNet model ~~~~~~~~~~")
    modelName = "Test_Model"
    print(" Model Name: {}".format(modelName))

    ## CREATION OF YOUR MODEL
    net = UNet(num_classes).to(device)

    print(
        "Total params: {0:,}".format(
            sum(p.numel() for p in net.parameters() if p.requires_grad)
        )
    )

    # DEFINE YOUR OUTPUT COMPONENTS (e.g., SOFTMAX, LOSS FUNCTION, ETC)
    CE_loss = torch.nn.CrossEntropyLoss().to(device)

    ce_loss_weight = 0.7
    dice_loss_weight = 0.3

    ## PUT EVERYTHING IN GPU RESOURCES
    # if torch.cuda.is_available():
    #     net.cuda()
    #     softMax.cuda()
    #     CE_loss.cuda()

    ## DEFINE YOUR OPTIMIZER
    optimizer = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)

    ### To save statistics ####
    train_losses = []
    train_dc_losses = []
    val_losses = []
    # val_dc_losses = []

    best_loss_val = 1000

    directory = "Results/Statistics/" + modelName

    print("~~~~~~~~~~~ Starting the training ~~~~~~~~~~")
    if os.path.exists(directory) == False:
        os.makedirs(directory)

    ## START THE TRAINING

    ## FOR EACH EPOCH
    for epoch in range(total_epochs):
        net.train()

        num_batches = len(train_loader_full)
        print("Number of batches: ", num_batches)

        running_train_loss = 0
        running_dice_loss = 0

        # Training loop
        for idx, data in enumerate(train_loader_full):
            ### Set to zero all the gradients
            net.zero_grad()
            optimizer.zero_grad()

            ## GET IMAGES, LABELS and IMG NAMES
            images, labels, img_names = data

            ### From numpy to torch variables
            labels = utils.to_var(labels).to(device)
            images = utils.to_var(images).to(device)

            # Forward pass
            net_predictions = net(images) # Predictions have shape [batch_size, num_classes, height, width]

            # Get the segmentation classes
            segmentation_classes = utils.getTargetSegmentation(labels)
            # Modify segmentation classes to be one-hot encoded (shape [batch_size, num_classes, height, width])
            dice_target = F.one_hot(segmentation_classes, num_classes = num_classes).permute(0,3,1,2).contiguous()

            # Compute the loss
            loss_ce = ce_loss_weight * CE_loss(net_predictions, segmentation_classes)
            loss_dice = dice_loss_weight * DiceLoss()(net_predictions, dice_target)
            loss = loss_ce + loss_dice

            running_train_loss += loss.item()
            # dice_loss = dice_coefficient(net_predictions, labels)
            # dice_loss = utils.compute_dsc(net_predictions, labels)
            # running_dice_loss += dice_loss

            # Backprop
            loss.backward()
            optimizer.step()

            # Add the loss to the tensorboard every 5 batches
            if idx % 10 == 0:
                writer.add_scalar(
                    "Loss/train", running_train_loss / (idx + 1), epoch * len(train_loader_full) + idx
                )

            if idx % 100 == 0:
                # Also add visualizations of the images
                probs = torch.softmax(net_predictions, dim=1)
                y_pred = torch.argmax(probs, dim=1)
                writer.add_figure('predictions vs. actuals',
                            utils.plot_net_predictions(images, labels, y_pred, batch_size),
                            global_step=epoch * len(train_loader_full) + idx)

            # THIS IS JUST TO VISUALIZE THE TRAINING
            printProgressBar(
                idx + 1,
                num_batches,
                prefix="[Training] Epoch: {} ".format(epoch),
                length=15,
                suffix=" Loss: {:.4f}, ".format(running_train_loss / (idx + 1)),
            )

        train_loss = running_train_loss / num_batches
        train_losses.append(train_loss)

        train_dc_loss = running_dice_loss / num_batches
        train_dc_losses.append(train_dc_loss)

        net.eval()
        val_running_loss = 0
        val_running_dc = 0

        # Validation loop
        with torch.no_grad():
            for idx, data in enumerate(val_loader):
                images, labels, img_names = data

                labels = utils.to_var(labels).to(device)
                images = utils.to_var(images).to(device)

                net_predictions = net(images)

                segmentation_classes = utils.getTargetSegmentation(labels)
                dice_target = F.one_hot(segmentation_classes, num_classes = num_classes).permute(0,3,1,2).contiguous()

                loss_ce = ce_loss_weight * CE_loss(net_predictions, segmentation_classes)
                loss_dice = dice_loss_weight * DiceLoss()(net_predictions, dice_target)
                loss = loss_ce + loss_dice

                val_running_loss += loss.item()
                # dice_loss = dice_coefficient(net_predictions, labels)
                # dice_loss = utils.compute_dsc(net_predictions, labels)
                # val_running_dc += dice_loss

                if idx % 10 == 0:
                    writer.add_scalar(
                        "Loss/val",
                        val_running_loss / (idx + 1),
                        epoch * len(val_loader) + idx,
                    )

                printProgressBar(
                    idx + 1,
                    len(val_loader),
                    prefix="[Validation] Epoch: {} ".format(epoch),
                    length=15,
                    suffix=" Loss: {:.4f}, ".format(val_running_loss / (idx + 1)),
                )

        val_loss = val_running_loss / len(val_loader)
        val_losses.append(val_loss)
        # dc_loss = val_running_dc / len(val_loader)
        # val_dc_losses.append(dc_loss)

        # Check if model performed best and save it if true
        if val_loss < best_loss_val:
            best_loss_val = val_loss
            if not os.path.exists("./models/" + modelName):
                os.makedirs("./models/" + modelName)
            torch.save(
                net.state_dict(), "./models/" + modelName + "/" + str(epoch) + "_Epoch"
            )
        
        printProgressBar(
            num_batches,
            num_batches,
            done="[Epoch: {}, TrainLoss: {:.4f}, TrainDice: {:.4f}, ValLoss: {:.4f}".format(
                epoch, train_loss, train_dc_loss, val_loss
            ),
        )

        # Check if loss has not decreased for 10 epochs
        # if epoch > 10 and val_losses[-1] > val_losses[-10]:
        #     print("Stopping early as validation loss has not decreased for 10 epochs")
        #     break

        np.save(os.path.join(directory, "Losses.npy"), train_losses)
    writer.flush()  # Flush the writer to ensure that all the data is written to disk

# %%
# Set up Tensorboard writer
writer = SummaryWriter()
runTraining(writer)
writer.close()
# Out:
# ----------------------------------------
# ~~~~~~~~  Starting the training... ~~~~~~
# ----------------------------------------
# Using device: mps
# ~~~~~~~~~~~ Creating the UNet model ~~~~~~~~~~
#  Model Name: Test_Model
# Total params: 60,664
# ~~~~~~~~~~~ Starting the training ~~~~~~~~~~
# Number of batches:  13
# [Training] Epoch: 0 [DONE]
# [Validation] Epoch: 0 [DONE]
# [Epoch: 0, TrainLoss: 0.8825, TrainDice: 0.0000, ValLoss: 0.7755
# Number of batches:  13
# [Training] Epoch: 1 [DONE]
# [Validation] Epoch: 1 [DONE]
# [Epoch: 1, TrainLoss: 0.5348, TrainDice: 0.0000, ValLoss: 0.7002
# Number of batches:  13
# [Training] Epoch: 2 [DONE]
# [Validation] Epoch: 2 [DONE]
# [Epoch: 2, TrainLoss: 0.3154, TrainDice: 0.0000, ValLoss: 0.3123
# Number of batches:  13
# [Training] Epoch: 3 [DONE]
# [Validation] Epoch: 3 [DONE]
# [Epoch: 3, TrainLoss: 0.1781, TrainDice: 0.0000, ValLoss: 0.1475
# Number of batches:  13
# [Training] Epoch: 4 [DONE]
# [Validation] Epoch: 4 [DONE]
# [Epoch: 4, TrainLoss: 0.1282, TrainDice: 0.0000, ValLoss: 0.1312
# Number of batches:  13
# [Training] Epoch: 5 [DONE]
# [Validation] Epoch: 5 [DONE]
# [Epoch: 5, TrainLoss: 0.1044, TrainDice: 0.0000, ValLoss: 0.1189
# Number of batches:  13
# [Training] Epoch: 6 [DONE]
# [Validation] Epoch: 6 [DONE]
# [Epoch: 6, TrainLoss: 0.0934, TrainDice: 0.0000, ValLoss: 0.0993
# Number of batches:  13
# [Training] Epoch: 7 [DONE]
# [Validation] Epoch: 7 [DONE]
# [Epoch: 7, TrainLoss: 0.0858, TrainDice: 0.0000, ValLoss: 0.0926
# Number of batches:  13
# [Training] Epoch: 8 [DONE]
# [Validation] Epoch: 8 [DONE]
# [Epoch: 8, TrainLoss: 0.0798, TrainDice: 0.0000, ValLoss: 0.0872
# Number of batches:  13
# [Training] Epoch: 9 [DONE]
# [Validation] Epoch: 9 [DONE]
# [Epoch: 9, TrainLoss: 0.0776, TrainDice: 0.0000, ValLoss: 0.0946
# Number of batches:  13
# [Training] Epoch: 10 [DONE]
# [Validation] Epoch: 10 [DONE]
# [Epoch: 10, TrainLoss: 0.0746, TrainDice: 0.0000, ValLoss: 0.1032
# Number of batches:  13
# [Training] Epoch: 11 [DONE]
# [Validation] Epoch: 11 [DONE]
# [Epoch: 11, TrainLoss: 0.0721, TrainDice: 0.0000, ValLoss: 0.0822
# Number of batches:  13
# [Training] Epoch: 12 [DONE]
# [Validation] Epoch: 12 [DONE]
# [Epoch: 12, TrainLoss: 0.0708, TrainDice: 0.0000, ValLoss: 0.0825
# Number of batches:  13
# [Training] Epoch: 13 [DONE]
# [Validation] Epoch: 13 [DONE]
# [Epoch: 13, TrainLoss: 0.0688, TrainDice: 0.0000, ValLoss: 0.0800
# Number of batches:  13
# [Training] Epoch: 14 [DONE]
# [Validation] Epoch: 14 [DONE]
# [Epoch: 14, TrainLoss: 0.0661, TrainDice: 0.0000, ValLoss: 0.0754
# Number of batches:  13
# [Training] Epoch: 15 [DONE]
# [Validation] Epoch: 15 [DONE]
# [Epoch: 15, TrainLoss: 0.0643, TrainDice: 0.0000, ValLoss: 0.1421
# Number of batches:  13
# [Training] Epoch: 16 [DONE]
# [Validation] Epoch: 16 [DONE]
# [Epoch: 16, TrainLoss: 0.0688, TrainDice: 0.0000, ValLoss: 0.0913
# Number of batches:  13
# [Training] Epoch: 17 [DONE]
# [Validation] Epoch: 17 [DONE]
# [Epoch: 17, TrainLoss: 0.0632, TrainDice: 0.0000, ValLoss: 0.1093
# Number of batches:  13
# [Training] Epoch: 18 [DONE]
# [Validation] Epoch: 18 [DONE]
# [Epoch: 18, TrainLoss: 0.0618, TrainDice: 0.0000, ValLoss: 0.0943
# Number of batches:  13
# [Training] Epoch: 19 [DONE]
# [Validation] Epoch: 19 [DONE]
# [Epoch: 19, TrainLoss: 0.0591, TrainDice: 0.0000, ValLoss: 0.0756
# Number of batches:  13
# [Training] Epoch: 20 [DONE]
# [Validation] Epoch: 20 [DONE]
# [Epoch: 20, TrainLoss: 0.0563, TrainDice: 0.0000, ValLoss: 0.0648
# Number of batches:  13
# [Training] Epoch: 21 [DONE]
# [Validation] Epoch: 21 [DONE]
# [Epoch: 21, TrainLoss: 0.0572, TrainDice: 0.0000, ValLoss: 0.1012
# Number of batches:  13
# [Training] Epoch: 22 [DONE]
# [Validation] Epoch: 22 [DONE]
# [Epoch: 22, TrainLoss: 0.0566, TrainDice: 0.0000, ValLoss: 0.0826
# Number of batches:  13
# [Training] Epoch: 23 [DONE]
# [Validation] Epoch: 23 [DONE]
# [Epoch: 23, TrainLoss: 0.0573, TrainDice: 0.0000, ValLoss: 0.0703
# Number of batches:  13
# [Training] Epoch: 24 [DONE]
# [Validation] Epoch: 24 [DONE]
# [Epoch: 24, TrainLoss: 0.0521, TrainDice: 0.0000, ValLoss: 0.0914
# Number of batches:  13
# [Training] Epoch: 25 [DONE]
# [Validation] Epoch: 25 [DONE]
# [Epoch: 25, TrainLoss: 0.0511, TrainDice: 0.0000, ValLoss: 0.0757
# Number of batches:  13
# [Training] Epoch: 26 [DONE]
# [Validation] Epoch: 26 [DONE]
# [Epoch: 26, TrainLoss: 0.0506, TrainDice: 0.0000, ValLoss: 0.0825
# Number of batches:  13
# [Training] Epoch: 27 [DONE]
# [Validation] Epoch: 27 [DONE]
# [Epoch: 27, TrainLoss: 0.0500, TrainDice: 0.0000, ValLoss: 0.0810
# Number of batches:  13
# [Training] Epoch: 28 [DONE]
# [Validation] Epoch: 28 [DONE]
# [Epoch: 28, TrainLoss: 0.0474, TrainDice: 0.0000, ValLoss: 0.0525
# Number of batches:  13
# [Training] Epoch: 29 [DONE]
# [Validation] Epoch: 29 [DONE]
# [Epoch: 29, TrainLoss: 0.0468, TrainDice: 0.0000, ValLoss: 0.0490
# Number of batches:  13
# [Training] Epoch: 30 [DONE]
# [Validation] Epoch: 30 [DONE]
# [Epoch: 30, TrainLoss: 0.0454, TrainDice: 0.0000, ValLoss: 0.0623
# Number of batches:  13
# [Training] Epoch: 31 [DONE]
# [Validation] Epoch: 31 [DONE]
# [Epoch: 31, TrainLoss: 0.0429, TrainDice: 0.0000, ValLoss: 0.0907
# Number of batches:  13
# [Training] Epoch: 32 [DONE]
# [Validation] Epoch: 32 [DONE]
# [Epoch: 32, TrainLoss: 0.0442, TrainDice: 0.0000, ValLoss: 0.0545
# Number of batches:  13
# [Training] Epoch: 33 [DONE]
# [Validation] Epoch: 33 [DONE]
# [Epoch: 33, TrainLoss: 0.0421, TrainDice: 0.0000, ValLoss: 0.0549
# Number of batches:  13
# [Training] Epoch: 34 [DONE]
# [Validation] Epoch: 34 [DONE]
# [Epoch: 34, TrainLoss: 0.0454, TrainDice: 0.0000, ValLoss: 0.0482
# Number of batches:  13
# [Training] Epoch: 35 [DONE]
# [Epoch: 82, TrainLoss: 0.0296, TrainDice: 0.0000, ValLoss: 0.0448
# Number of batches:  13
# [Training] Epoch: 83 [DONE]
# [Validation] Epoch: 83 [DONE]
# [Epoch: 83, TrainLoss: 0.0298, TrainDice: 0.0000, ValLoss: 0.0531
# Number of batches:  13
# [Training] Epoch: 84 [DONE]
# [Validation] Epoch: 84 [DONE]
# [Epoch: 84, TrainLoss: 0.0279, TrainDice: 0.0000, ValLoss: 0.0630
# Number of batches:  13
# [Training] Epoch: 85 [DONE]
# [Validation] Epoch: 85 [DONE]
# [Epoch: 85, TrainLoss: 0.0261, TrainDice: 0.0000, ValLoss: 0.0448
# Number of batches:  13
# [Training] Epoch: 86 [DONE]
# [Validation] Epoch: 86 [DONE]
# [Epoch: 86, TrainLoss: 0.0267, TrainDice: 0.0000, ValLoss: 0.0399
# Number of batches:  13
# [Training] Epoch: 87 [DONE]
# [Validation] Epoch: 87 [DONE]
# [Epoch: 87, TrainLoss: 0.0249, TrainDice: 0.0000, ValLoss: 0.0534
# Number of batches:  13
# [Training] Epoch: 88 [DONE]
# [Validation] Epoch: 88 [DONE]
# [Epoch: 88, TrainLoss: 0.0265, TrainDice: 0.0000, ValLoss: 0.0494
# Number of batches:  13
# [Training] Epoch: 89 [DONE]
# [Validation] Epoch: 89 [DONE]
# [Epoch: 89, TrainLoss: 0.0255, TrainDice: 0.0000, ValLoss: 0.0793
# Number of batches:  13
# [Training] Epoch: 90 [DONE]
# [Validation] Epoch: 90 [DONE]
# [Epoch: 90, TrainLoss: 0.0257, TrainDice: 0.0000, ValLoss: 0.0621
# Number of batches:  13
# [Training] Epoch: 91 [DONE]
# [Validation] Epoch: 91 [DONE]
# [Epoch: 91, TrainLoss: 0.0266, TrainDice: 0.0000, ValLoss: 0.0740
# Number of batches:  13
# [Training] Epoch: 92 [DONE]
# [Validation] Epoch: 92 [DONE]
# [Epoch: 92, TrainLoss: 0.0245, TrainDice: 0.0000, ValLoss: 0.0711
# Number of batches:  13
# [Training] Epoch: 93 [DONE]
# [Validation] Epoch: 93 [DONE]
# [Epoch: 93, TrainLoss: 0.0274, TrainDice: 0.0000, ValLoss: 0.0582
# Number of batches:  13
# [Training] Epoch: 94 [DONE]
# [Validation] Epoch: 94 [DONE]
# [Epoch: 94, TrainLoss: 0.0254, TrainDice: 0.0000, ValLoss: 0.0379
# Number of batches:  13
# [Training] Epoch: 95 [DONE]
# [Validation] Epoch: 95 [DONE]
# [Epoch: 95, TrainLoss: 0.0241, TrainDice: 0.0000, ValLoss: 0.0920
# Number of batches:  13
# [Training] Epoch: 96 [DONE]
# [Validation] Epoch: 96 [DONE]
# [Epoch: 96, TrainLoss: 0.0231, TrainDice: 0.0000, ValLoss: 0.0501
# Number of batches:  13
# [Training] Epoch: 97 [DONE]
# [Validation] Epoch: 97 [DONE]
# [Epoch: 97, TrainLoss: 0.0226, TrainDice: 0.0000, ValLoss: 0.0569
# Number of batches:  13
# [Training] Epoch: 98 [DONE]
# [Validation] Epoch: 98 [DONE]
# [Epoch: 98, TrainLoss: 0.0238, TrainDice: 0.0000, ValLoss: 0.0576
# Number of batches:  13
# [Training] Epoch: 99 [DONE]
# [Validation] Epoch: 99 [DONE]
# [Epoch: 99, TrainLoss: 0.0220, TrainDice: 0.0000, ValLoss: 0.0517
# Number of batches:  13
# [Training] Epoch: 100 [DONE]
# [Validation] Epoch: 100 [DONE]
# [Epoch: 100, TrainLoss: 0.0209, TrainDice: 0.0000, ValLoss: 0.0433
# Number of batches:  13
# [Training] Epoch: 101 [DONE]
# [Validation] Epoch: 101 [DONE]
# [Epoch: 101, TrainLoss: 0.0236, TrainDice: 0.0000, ValLoss: 0.0542
# Number of batches:  13
# [Training] Epoch: 102 [DONE]
# [Validation] Epoch: 102 [DONE]
# [Epoch: 102, TrainLoss: 0.0252, TrainDice: 0.0000, ValLoss: 0.0353
# Number of batches:  13
# [Training] Epoch: 103 [DONE]
# [Validation] Epoch: 103 [DONE]
# [Epoch: 103, TrainLoss: 0.0265, TrainDice: 0.0000, ValLoss: 0.0362
# Number of batches:  13
# [Training] Epoch: 104 [DONE]
# [Validation] Epoch: 104 [DONE]
# [Epoch: 104, TrainLoss: 0.0264, TrainDice: 0.0000, ValLoss: 0.0546
# Number of batches:  13
# [Training] Epoch: 105 [DONE]
# [Validation] Epoch: 105 [DONE]
# [Epoch: 105, TrainLoss: 0.0226, TrainDice: 0.0000, ValLoss: 0.0689
# Number of batches:  13
# [Training] Epoch: 106 [DONE]
# [Validation] Epoch: 106 [DONE]
# [Epoch: 106, TrainLoss: 0.0216, TrainDice: 0.0000, ValLoss: 0.0503
# Number of batches:  13
# [Training] Epoch: 107 [DONE]
# [Validation] Epoch: 107 [DONE]
# [Epoch: 107, TrainLoss: 0.0220, TrainDice: 0.0000, ValLoss: 0.0573
# Number of batches:  13
# [Training] Epoch: 108 [DONE]
# [Validation] Epoch: 108 [DONE]
# [Epoch: 108, TrainLoss: 0.0259, TrainDice: 0.0000, ValLoss: 0.0520
# Number of batches:  13
# [Training] Epoch: 109 [DONE]
# [Validation] Epoch: 109 [DONE]
# [Epoch: 109, TrainLoss: 0.0263, TrainDice: 0.0000, ValLoss: 0.0423
# Number of batches:  13
# [Training] Epoch: 110 [DONE]
# [Validation] Epoch: 110 [DONE]
# [Epoch: 110, TrainLoss: 0.0230, TrainDice: 0.0000, ValLoss: 0.0372
# Number of batches:  13
# [Training] Epoch: 111 [DONE]
# [Validation] Epoch: 111 [DONE]
# [Epoch: 111, TrainLoss: 0.0244, TrainDice: 0.0000, ValLoss: 0.0524
# Number of batches:  13
# [Training] Epoch: 112 [DONE]
# [Validation] Epoch: 112 [DONE]
# [Epoch: 112, TrainLoss: 0.0245, TrainDice: 0.0000, ValLoss: 0.0617
# Number of batches:  13
# [Training] Epoch: 113 [DONE]
# [Validation] Epoch: 113 [DONE]
# [Epoch: 113, TrainLoss: 0.0245, TrainDice: 0.0000, ValLoss: 0.0362
# Number of batches:  13
# [Training] Epoch: 114 [DONE]
# [Validation] Epoch: 114 [DONE]
# [Epoch: 114, TrainLoss: 0.0234, TrainDice: 0.0000, ValLoss: 0.0578
# Number of batches:  13
# [Training] Epoch: 115 [DONE]
# [Validation] Epoch: 115 [DONE]
# [Epoch: 115, TrainLoss: 0.0225, TrainDice: 0.0000, ValLoss: 0.0517
# Number of batches:  13
# [Training] Epoch: 116 [DONE]
# [Validation] Epoch: 116 [DONE]
# [Epoch: 116, TrainLoss: 0.0226, TrainDice: 0.0000, ValLoss: 0.0437
# Number of batches:  13
# [Training] Epoch: 117 [DONE]
# [Validation] Epoch: 117 [DONE]
# [Epoch: 117, TrainLoss: 0.0235, TrainDice: 0.0000, ValLoss: 0.0658
# Number of batches:  13
# [Training] Epoch: 118 [DONE]
# [Validation] Epoch: 118 [DONE]
# [Epoch: 118, TrainLoss: 0.0238, TrainDice: 0.0000, ValLoss: 0.0535
# Number of batches:  13
# [Training] Epoch: 119 [DONE]
# [Validation] Epoch: 119 [DONE]
# [Epoch: 119, TrainLoss: 0.0225, TrainDice: 0.0000, ValLoss: 0.0577

# %%
from utils import inference

epoch_to_load = 0
model = UNet(4)
model.load_state_dict(torch.load(f"./models/Test_Model/{epoch_to_load}_Epoch"))
inf_losses = inference(model, val_loader, "test", epoch_to_load)
# Out:
# [Inference] Getting segmentations...[>                             ] 0.0%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[=>                            ] 5.3%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[===>                          ] 10.5%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[====>                         ] 15.8%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[======>                       ] 21.1%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[=======>                      ] 26.3%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[=========>                    ] 31.6%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[===========>                  ] 36.8%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[============>                 ] 42.1%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[==============>               ] 47.4%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[===============>              ] 52.6%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[=================>            ] 57.9%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[==================>           ] 63.2%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[====================>         ] 68.4%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[======================>       ] 73.7%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[=======================>      ] 78.9%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[=========================>    ] 84.2%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[==========================>   ] 89.5%torch.Size([4, 4, 256, 256])
# [Inference] Getting segmentations...[============================> ] 94.7%torch.Size([2, 4, 256, 256])
# [Inference] Segmentation Done !
