# %% [markdown]
# # Project MTI865 - Heart segmentation using UNet
#
# ---
#
# # Model training - CE-DSC with Transformation consistency (MSE)
#
# $$
# \mathcal{L} = \frac{1}{n_{l}} \left(w_{CE} \mathcal{L}_{CE} + w_{DSC} \mathcal{L}_{DSC} \right)  + \frac{\alpha_{TC}}{n_{u}} \mathcal{L}_{TC-MSE}
# $$
#
# PAS ENCORE IMPLEMENTÉ !!!!

# %% [markdown]
# ## Import libraries

# %%
# adding .. to path 
import sys 
sys.path.append('..')

# %%
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision.transforms import v2
from progressBar import printProgressBar

import medicalDataLoader
import argparse
import utils

from UNet_Base import *
import random
import torch
import pdb
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading data

# %%
batch_size = 4
batch_size_val = 4
batch_size_unlabel = 8

# %%
# Define image and mask transformations
transform = v2.Compose([
    v2.ToTensor(),
    v2.Normalize(mean=[0.137], std=[0.1733]) # Normalisation values for the training set (mean and std) 
])

mask_transform = v2.Compose([
    v2.ToTensor(),
])

# %%
def collate_fn(batch):
    """
    Fonction de regroupement pour le DataLoader.

    Args:
    -----
        batch (list): Liste de tuples (image, masque, chemin de l'image).

    Returns:
    -------
        imgs_tensor (torch.Tensor): Batch d'images.
        masks_tensor (torch.Tensor): Batch de masques.
        img_paths (list): Liste des chemins des images.
    """
    imgs = []
    masks = []
    img_paths = []

    for item in batch:
        img, mask, img_path = item[0], item[1], item[2]
        imgs.append(img)
        img_paths.append(img_path)
        
        # Si le masque est None, ajouter un tenseur de zéros correspondant à sa taille
        if mask is not None:
            masks.append(mask)
        else:
            masks.append(torch.zeros_like(img[0, :, :]))  # Même taille que le canal de l'image (assumant CxHxW)

    # Stack les images et les masques
    imgs_tensor = torch.stack(imgs)  # Tensor de forme (B, C, H, W)
    masks_tensor = torch.stack(masks)  # Tensor de forme (B, H, W)

    return imgs_tensor, masks_tensor, img_paths

# %%
# Define dataloaders
root_dir = '../data/'
print(' Dataset: {} '.format(root_dir))

supervised_set = medicalDataLoader.MedicalImageDataset(
    'train',
    root_dir,
    transform=transform,
    mask_transform=mask_transform,
    augment=True,
    equalize=False)


supervised_loader = DataLoader(
    supervised_set,
    batch_size=batch_size,
    worker_init_fn=np.random.seed(0),
    num_workers=0,
    shuffle=True,
    collate_fn=collate_fn)


val_set = medicalDataLoader.MedicalImageDataset(
    'val',  
    root_dir,
    transform=transform,
    mask_transform=mask_transform,
    equalize=False)

val_loader = DataLoader(
    val_set,
    batch_size=batch_size_val,
    worker_init_fn=np.random.seed(0),
    num_workers=0,
    shuffle=False)

unsupervised_set = medicalDataLoader.MedicalImageDataset(
    'train-unlabelled',
    root_dir,
    transform=transform,
    mask_transform=mask_transform,
    augment=False,
    equalize=False)

unsupervised_loader = DataLoader(
    unsupervised_set,
    batch_size=batch_size_unlabel,
    worker_init_fn=np.random.seed(0),
    num_workers=0,
    shuffle=False,
    collate_fn=collate_fn)



print('Train set: ', len(supervised_set))
print('Validation set: ', len(val_set))

n_train_label = len(supervised_set)
n_train_unlabel = len(unsupervised_set)

# shape of the image a  nd mask
img, mask, _ = supervised_set[0]
print('Image shape: ', img.shape)
print('Mask shape: ', mask.shape)
print('Number of batches: ', len(supervised_loader))

img, mask, _ = val_set[0]
print('Image shape: ', img.shape)
print('Mask shape: ', mask.shape)
print('Number of batches: ', len(val_loader))

img, _, __ = unsupervised_set[0]
print('Image shape: ', img.shape)
print('Mask shape: ', mask.shape)
print('Number of batches: ', len(unsupervised_loader))


# print('First of the supervised set')
# img, mask, path_tuple = supervised_set[0]
# print(img)
# print(mask)
# print(path_tuple)

# print('First of the unsupervised set')
# img, mask, path_tuple = unsupervised_set[0]
# print(img)
# print(mask)
# print(path_tuple)
# Out:
#  Dataset: ../data/
# Found 204 items in train
# First item:  ('../data/train\\Img\\patient006_01_1.png', '../data/train\\GT\\patient006_01_1.png')
# Found 74 items in val
# First item:  ('../data/val\\Img\\patient001_01_1.png', '../data/val\\GT\\patient001_01_1.png')
# Found 1004 items in train-unlabelled
# First item:  ('../data/train\\Img-Unlabeled\\patient007_01_1.png', None)
# Train set:  204
# Validation set:  74
# Image shape:  torch.Size([1, 256, 256])
# Mask shape:  torch.Size([1, 256, 256])
# Number of batches:  51
# Image shape:  torch.Size([1, 256, 256])
# Mask shape:  torch.Size([1, 256, 256])
# Number of batches:  19
# Image shape:  torch.Size([1, 256, 256])
# Mask shape:  torch.Size([1, 256, 256])
# Number of batches:  126

# %% [markdown]
# ## Model using both labeled and unlabeled data

# %% [markdown]
# ### Hyperparameters of the model

# %%
# Parameters 
lr =  0.0005    # Learning Rate
total_epochs = 100  # Number of epochs
weight_TC = 0.1 # Alpha parameter for the consistency loss term 
weight_decay = 1e-5  # Weight decay
ce_loss_weight = 0.8 # Cross Entropy Loss Weight proportion
dice_loss_weight = 0.2 # Dice Loss Weight proportion 

modelName = f"allModel-{total_epochs}epochs{lr}lr{weight_TC}alphaTC{weight_decay}wd"
model_dir = f"models/{modelName}"
# write params in a file 
param_dict = {
    "lr": lr,
    "total_epochs": total_epochs,
    "weight_TC": weight_TC,
    "weight_decay": weight_decay,
    "ce_loss_weight": ce_loss_weight,
    "dice_loss_weight": dice_loss_weight,
    "modelName": modelName,
    "model": "ALL"
}


os.makedirs(model_dir, exist_ok=True)
with open(f"{model_dir}/params.txt", 'w') as f:
    print(param_dict, file=f)

print(f"Parameters saved to {model_dir}/params.txt")

print(f"Parameters saved to {model_dir}/params.txt")
# Out:
# Parameters saved to models/TransformationConsistencyL2Model-150epochs0.0005lr0.1alphaTC1e-05wd/params.txt
# Parameters saved to models/TransformationConsistencyL2Model-150epochs0.0005lr0.1alphaTC1e-05wd/params.txt

# %% [markdown]
# ### Transformation consistency regularisation
#
# The transformation consistency consists in the principle that transformation T suchs as rotation and flipping should affect the mask f(y) only by the same rotation, which means that f and T should be symetrical. In this implementation, we used the 2-norm to measure the difference, and we included it in the optimisation problem.  $\mathcal{L}_{TC}(y_u) = \|f(T(y_u))-T(F(y))\|_2$.
# Il est aussi possible de faire une régularisation avec la CE :

# %%
from torchvision import transforms

class ConsistencyRegularization(nn.Module):
    def __init__(self, transformation_fn, loss_fn=nn.MSELoss()):
        """
        Régularisation basée sur la consistance à la transformation.

        Args:
        -----
            transformation_fn (callable): Fonction d'augmentation/transformation appliquée aux images.
            loss_fn (callable): Fonction de perte utilisée pour comparer les prédictions (par défaut MSELoss). Aussi possible d'utiliser 
                                nn.KLDivLoss ou nn.BCELoss.
        """
        super(ConsistencyRegularization, self).__init__()
        self.transformation_fn = transformation_fn
        self.loss_fn = loss_fn

    def forward(self, model, images):
        """
        Calcule la perte de consistance.

        Args:
            model (torch.nn.Module): Le modèle de segmentation.
            images (torch.Tensor): Batch d'images d'entrée.

        Returns:
            torch.Tensor: La perte de consistance.
        """
        with torch.no_grad():
            # Prédictions de base
            original_predictions = F.softmax(model(images), dim=1)

        # Augmenter les images
        augmented_images = self.transformation_fn(images)

        # Prédictions pour les images augmentées
        augmented_predictions = F.softmax(model(augmented_images), dim=1)

        # Calcul de la perte de consistance
        consistency_loss = self.loss_fn(original_predictions, augmented_predictions)

        return consistency_loss

# %%
def random_transformation_fn(images):
  
    # Random horizontal flip
    if np.random.random() > 0.5:
        images = torch.flip(images, dims=[2])
    # Random vertical flip
    if np.random.random() > 0.5:
        images = torch.flip(images, dims=[3])
    # Random rotation of random angle
    if np.random.random() > 0.5:
        angle = np.random.randint(0, 360)
        images = torch.rot90(images, k=angle//90, dims=[2, 3])
    return images

# %% [markdown]
# ### Training of the model
#
# At each epoch, the model sees once every exemple of unlabeled data, and sees several time the labeled data. We first train it with the labeled data, and then we train it on the unsupervised data.

# %%
writer = SummaryWriter()

print("-" * 40)
print("~~~~~~~~  Starting the training... ~~~~~~")
print("-" * 40)

num_classes = 4

# Set device depending on the availability of GPU
if torch.cuda.is_available():
    device = torch.device("cuda")
# elif torch.mps.is_available():  # Apple M-series of chips
#     device = torch.device("mps")
else:
    device = torch.device("cpu")

print(f"Using device: {device}")

print("~~~~~~~~~~~ Creating the UNet model ~~~~~~~~~~")
print(" Model Name: {}".format(modelName))

## CREATION OF YOUR MODEL
net = UNet(num_classes).to(device)

print(
    "Total params: {0:,}".format(
        sum(p.numel() for p in net.parameters() if p.requires_grad)
    )
)

# DEFINE YOUR OUTPUT COMPONENTS (e.g., SOFTMAX, LOSS FUNCTION, ETC)
softMax = torch.nn.Softmax(dim=1)
CE_loss = torch.nn.CrossEntropyLoss()
consistency_regularizer = ConsistencyRegularization(transformation_fn=random_transformation_fn)


## PUT EVERYTHING IN GPU RESOURCES
if torch.cuda.is_available():
    net.cuda()
    softMax.cuda()
    CE_loss.cuda()

## DEFINE YOUR OPTIMIZER
optimizer = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)

### To save statistics ####
train_losses = []
train_dc_losses = []
val_losses = []
val_dc_losses = []

best_loss_val = 1000

directory = "Results/Statistics/" + modelName

print("~~~~~~~~~~~ Starting the training ~~~~~~~~~~")
if os.path.exists(directory) == False:
    os.makedirs(directory)

## START THE TRAINING

## FOR EACH EPOCH
for epoch in range(total_epochs):
    net.train()
    supervised_iter = iter(supervised_loader)
    unsupervised_iter = iter(unsupervised_loader)
    
    num_batches = max(len(supervised_loader), len(unsupervised_loader))
    print("Number of batches: ", num_batches)

    running_train_loss = 0
    running_dice_loss = 0

    # Training loop
    for idx in range(num_batches):
        ### SUPERVISED BATCH
        try :
            supervised_data = next(supervised_iter)
        except StopIteration:
            supervised_iter = iter(supervised_loader)
            supervised_data = next(supervised_iter)

        ### Set to zero all the gradients
        net.zero_grad()
        optimizer.zero_grad()

        ## GET IMAGES, LABELS and IMG NAMES
        images, labels, img_names = supervised_data

        ### From numpy to torch variables
        labels = utils.to_var(labels).to(device)
        images = utils.to_var(images).to(device)

        # Forward pass
        net_predictions = net(images)

        # Get the segmentation classes
        segmentation_classes = utils.getTargetSegmentation(labels)
        # Modify segmentation classes to be one-hot encoded (shape [batch_size, num_classes, height, width])
        dice_target = F.one_hot(segmentation_classes, num_classes = num_classes).permute(0,3,1,2).contiguous()

        # Compute the loss
        ce_loss = ce_loss_weight * CE_loss(net_predictions, segmentation_classes) 
        dice_loss = dice_loss_weight * DiceLoss()(net_predictions, dice_target)  
        loss = ce_loss + dice_loss 
        running_train_loss += ce_loss.item() + dice_loss.item() 
        # dice_loss = dice_coefficient(net_predictions, labels)
        # dice_loss = utils.compute_dsc(net_predictions, labels)
        running_dice_loss += dice_loss

        # Backprop
        loss.backward()
        optimizer.step()

        ### UNSUPERVISED BATCH
        try :
            unsupervised_data = next(unsupervised_iter)
        except StopIteration:
            unsupervised_iter = iter(unsupervised_loader)
            unsupervised_data = next(unsupervised_iter)
        
        unsupervised_images, _, __ = unsupervised_data
        unsupervised_images = utils.to_var(unsupervised_images).to(device)

        net.zero_grad()
        optimizer.zero_grad()

        consistency_loss = weight_TC * consistency_regularizer(net, unsupervised_images) 
        loss = consistency_loss
        
        loss.backward()
        optimizer.step()

        running_train_loss += consistency_loss.item()
        running_dice_loss += 0

        # Add the loss to the tensorboard every 5 batches
        if idx % 10 == 0:
            writer.add_scalar(
                "Loss/train", running_train_loss / (idx + 1), epoch * len(supervised_loader) + idx
            )
            writer.add_scalar(
                "Dice/train", running_dice_loss / (idx + 1), epoch * len(supervised_loader) + idx
            )

        if idx % 100 == 0:
            # Also add visualizations of the images
            probs = torch.softmax(net_predictions, dim=1)
            y_pred = torch.argmax(probs, dim=1)
            writer.add_figure('predictions vs. actuals',
                        utils.plot_net_predictions(images, labels, y_pred, batch_size),
                        global_step=epoch * len(supervised_loader) + idx)

        # THIS IS JUST TO VISUALIZE THE TRAINING
        printProgressBar(
            idx + 1,
            num_batches,
            prefix="[Training] Epoch: {} ".format(epoch),
            length=15,
            suffix=" Loss: {:.4f}, ".format(running_train_loss / (idx + 1)),
        )
        # print(f"Epoch {epoch}, Batch {idx}, CE_loss: {ce_loss.item()}, Dice_loss: {dice_loss.item()}, Consistency_loss: {consistency_loss.item()}")

    train_loss = running_train_loss / num_batches
    train_losses.append(train_loss)

    train_dc_loss = running_dice_loss / num_batches
    train_dc_losses.append(train_dc_loss)
    # print(f"Epoch {epoch}, Batch {idx}, CE_loss: {ce_loss.item()}, Dice_loss: {dice_loss.item()}, Consistency_loss: {consistency_loss.item()}")
    net.eval()
    val_running_loss = 0
    val_running_dc = 0

    # Validation loop
    with torch.no_grad():
        for idx, data in enumerate(val_loader):
            images, labels, img_names = data

            labels = utils.to_var(labels).to(device)
            images = utils.to_var(images).to(device)

            net_predictions = net(images)

            segmentation_classes = utils.getTargetSegmentation(labels)

            loss = CE_loss(net_predictions, segmentation_classes) 
            val_running_loss += loss.item()

            # dice_loss = dice_coefficient(net_predictions, labels)
            dice_loss = utils.compute_dsc(net_predictions, labels)
            val_running_dc += dice_loss

            if idx % 10 == 0:
                writer.add_scalar(
                    "Loss/val",
                    val_running_loss / (idx + 1),
                    epoch * len(val_loader) + idx,
                )
                writer.add_scalar(
                    "Dice/val",
                    val_running_dc / (idx + 1),
                    epoch * len(val_loader) + idx,
                )

            printProgressBar(
                idx + 1,
                len(val_loader),
                prefix="[Validation] Epoch: {} ".format(epoch),
                length=15,
                suffix=" Loss: {:.4f}, ".format(val_running_loss / (idx + 1)),
            )

    val_loss = val_running_loss / len(val_loader)
    val_losses.append(val_loss)
    dc_loss = val_running_dc / len(val_loader)
    val_dc_losses.append(dc_loss)

    # Check if model performed best and save it if true
    if val_loss < best_loss_val:
        best_loss_val = val_loss
        if not os.path.exists("./models/" + modelName):
            os.makedirs("./models/" + modelName)
        torch.save(
            net.state_dict(), "./models/" + modelName + "/" + str(epoch) + "_Epoch"
        )

    printProgressBar(
        num_batches,
        num_batches,
        done="[Epoch: {}, TrainLoss: {:.4f}, TrainDice: {:.4f}, ValLoss: {:.4f}".format(
            epoch, train_loss, train_dc_loss, val_loss
        ),
    )

    np.save(os.path.join(directory, "Losses.npy"), train_losses)
writer.flush()  # Flush the writer to ensure that all the data is written to disk
writer.close()
# Out:
# ----------------------------------------
# ~~~~~~~~  Starting the training... ~~~~~~
# ----------------------------------------
# Using device: cpu
# ~~~~~~~~~~~ Creating the UNet model ~~~~~~~~~~
#  Model Name: TransformationConsistencyL2Model-150epochs0.0005lr0.1alphaTC1e-05wd
# Total params: 60,664
# ~~~~~~~~~~~ Starting the training ~~~~~~~~~~
# Number of batches:  126
# [Training] Epoch: 0 [DONE]
# [Validation] Epoch: 0 [DONE]
# [Epoch: 0, TrainLoss: 1.0398, TrainDice: 0.1571, ValLoss: 0.9892
# Number of batches:  126
# [Training] Epoch: 1 [DONE]
# [Validation] Epoch: 1 [DONE]
# [Epoch: 1, TrainLoss: 0.6703, TrainDice: 0.0958, ValLoss: 0.7030
# Number of batches:  126
# [Training] Epoch: 2 [DONE]
# [Validation] Epoch: 2 [DONE]
# [Epoch: 2, TrainLoss: 0.4673, TrainDice: 0.0568, ValLoss: 0.5044
# Number of batches:  126
# [Training] Epoch: 3 [DONE]
# [Validation] Epoch: 3 [DONE]
# [Epoch: 3, TrainLoss: 0.3273, TrainDice: 0.0324, ValLoss: 0.3732
# Number of batches:  126
# [Training] Epoch: 4 [DONE]
# [Validation] Epoch: 4 [DONE]
# [Epoch: 4, TrainLoss: 0.2399, TrainDice: 0.0198, ValLoss: 0.2906
# Number of batches:  126
# [Training] Epoch: 5 [DONE]
# [Validation] Epoch: 5 [DONE]
# [Epoch: 5, TrainLoss: 0.1839, TrainDice: 0.0136, ValLoss: 0.2125
# Number of batches:  126
# [Training] Epoch: 6 [DONE]
# [Validation] Epoch: 6 [DONE]
# [Epoch: 6, TrainLoss: 0.1387, TrainDice: 0.0094, ValLoss: 0.1681
# Number of batches:  126
# [Training] Epoch: 7 [DONE]
# [Validation] Epoch: 7 [DONE]
# [Epoch: 7, TrainLoss: 0.1114, TrainDice: 0.0073, ValLoss: 0.1683
# Number of batches:  126
# [Training] Epoch: 8 [DONE]
# [Validation] Epoch: 8 [DONE]
# [Epoch: 8, TrainLoss: 0.0929, TrainDice: 0.0061, ValLoss: 0.1333
# Number of batches:  126
# [Training] Epoch: 9 [DONE]
# [Validation] Epoch: 9 [DONE]
# [Epoch: 9, TrainLoss: 0.0819, TrainDice: 0.0056, ValLoss: 0.1292
# Number of batches:  126
# [Training] Epoch: 10 [DONE]
# [Validation] Epoch: 10 [DONE]
# [Epoch: 10, TrainLoss: 0.0736, TrainDice: 0.0052, ValLoss: 0.1341
# Number of batches:  126
# [Training] Epoch: 11 [DONE]
# [Validation] Epoch: 11 [DONE]
# [Epoch: 11, TrainLoss: 0.0679, TrainDice: 0.0051, ValLoss: 0.1009
# Number of batches:  126
# [Training] Epoch: 12 [DONE]
# [Validation] Epoch: 12 [DONE]
# [Epoch: 12, TrainLoss: 0.0620, TrainDice: 0.0048, ValLoss: 0.1286
# Number of batches:  126
# [Training] Epoch: 13 [DONE]
# [Validation] Epoch: 13 [DONE]
# [Epoch: 13, TrainLoss: 0.0587, TrainDice: 0.0047, ValLoss: 0.0875
# Number of batches:  126
# [Training] Epoch: 14 [DONE]
# [Validation] Epoch: 14 [DONE]
# [Epoch: 14, TrainLoss: 0.0542, TrainDice: 0.0044, ValLoss: 0.0881
# Number of batches:  126
# [Training] Epoch: 15 [DONE]
# [Validation] Epoch: 15 [DONE]
# [Epoch: 15, TrainLoss: 0.0513, TrainDice: 0.0043, ValLoss: 0.1074
# Number of batches:  126
# [Training] Epoch: 16 [DONE]
# [Validation] Epoch: 16 [DONE]
# [Epoch: 16, TrainLoss: 0.0491, TrainDice: 0.0042, ValLoss: 0.1282
# Number of batches:  126
# [Training] Epoch: 17 [DONE]
# [Validation] Epoch: 17 [DONE]
# [Epoch: 17, TrainLoss: 0.0477, TrainDice: 0.0041, ValLoss: 0.1051
# Number of batches:  126
# [Training] Epoch: 18 [DONE]
# [Validation] Epoch: 18 [DONE]
# [Epoch: 18, TrainLoss: 0.0450, TrainDice: 0.0040, ValLoss: 0.0715
# Number of batches:  126
# [Training] Epoch: 19 [DONE]
# [Validation] Epoch: 19 [DONE]
# [Epoch: 19, TrainLoss: 0.0447, TrainDice: 0.0040, ValLoss: 0.1053
# Number of batches:  126
# [Training] Epoch: 20 [DONE]
# [Validation] Epoch: 20 [DONE]
# [Epoch: 20, TrainLoss: 0.0423, TrainDice: 0.0038, ValLoss: 0.0977
# Number of batches:  126
# [Training] Epoch: 21 [DONE]
# [Validation] Epoch: 21 [DONE]
# [Epoch: 21, TrainLoss: 0.0410, TrainDice: 0.0037, ValLoss: 0.0618
# Number of batches:  126
# [Training] Epoch: 22 [DONE]
# [Validation] Epoch: 22 [DONE]
# [Epoch: 22, TrainLoss: 0.0396, TrainDice: 0.0037, ValLoss: 0.0573
# Number of batches:  126
# [Training] Epoch: 23 [DONE]
# [Validation] Epoch: 23 [DONE]
# [Epoch: 23, TrainLoss: 0.0385, TrainDice: 0.0036, ValLoss: 0.0828
# Number of batches:  126
# [Training] Epoch: 24 [DONE]
# [Validation] Epoch: 24 [DONE]
# [Epoch: 24, TrainLoss: 0.0371, TrainDice: 0.0035, ValLoss: 0.1029
# Number of batches:  126
# [Training] Epoch: 25 [DONE]
# [Validation] Epoch: 25 [DONE]
# [Epoch: 25, TrainLoss: 0.0352, TrainDice: 0.0033, ValLoss: 0.0569
# Number of batches:  126
# [Training] Epoch: 26 [DONE]
# [Validation] Epoch: 26 [DONE]
# [Epoch: 26, TrainLoss: 0.0343, TrainDice: 0.0033, ValLoss: 0.0884
# Number of batches:  126
# [Training] Epoch: 27 [DONE]
# [Validation] Epoch: 27 [DONE]
# [Epoch: 27, TrainLoss: 0.0331, TrainDice: 0.0032, ValLoss: 0.0505
# Number of batches:  126
# [Training] Epoch: 28 [DONE]
# [Validation] Epoch: 28 [DONE]
# [Epoch: 28, TrainLoss: 0.0333, TrainDice: 0.0032, ValLoss: 0.0830
# Number of batches:  126
# [Training] Epoch: 29 [DONE]
# [Validation] Epoch: 29 [DONE]
# [Epoch: 29, TrainLoss: 0.0322, TrainDice: 0.0031, ValLoss: 0.0532
# Number of batches:  126
# [Training] Epoch: 30 [DONE]
# [Validation] Epoch: 30 [DONE]
# [Epoch: 30, TrainLoss: 0.0316, TrainDice: 0.0030, ValLoss: 0.0752
# Number of batches:  126
# [Training] Epoch: 31 [DONE]
# [Validation] Epoch: 31 [DONE]
# [Epoch: 31, TrainLoss: 0.0308, TrainDice: 0.0030, ValLoss: 0.0790
# Number of batches:  126
# [Training] Epoch: 32 [DONE]
# [Validation] Epoch: 32 [DONE]
# [Epoch: 32, TrainLoss: 0.0295, TrainDice: 0.0029, ValLoss: 0.0831
# Number of batches:  126
# [Training] Epoch: 33 [DONE]
# [Validation] Epoch: 33 [DONE]
# [Epoch: 33, TrainLoss: 0.0297, TrainDice: 0.0029, ValLoss: 0.0869
# Number of batches:  126
# [Training] Epoch: 34 [DONE]
# [Validation] Epoch: 34 [DONE]
# [Epoch: 34, TrainLoss: 0.0294, TrainDice: 0.0028, ValLoss: 0.0670
# Number of batches:  126
# [Training] Epoch: 35 [DONE]
# [Validation] Epoch: 35 [DONE]
# [Epoch: 35, TrainLoss: 0.0288, TrainDice: 0.0028, ValLoss: 0.0552
# Number of batches:  126
# [Training] Epoch: 36 [DONE]
# [Validation] Epoch: 36 [DONE]
# [Epoch: 36, TrainLoss: 0.0266, TrainDice: 0.0026, ValLoss: 0.0893
# Number of batches:  126
# [Training] Epoch: 37 [DONE]
# [Validation] Epoch: 37 [DONE]
# [Epoch: 37, TrainLoss: 0.0271, TrainDice: 0.0026, ValLoss: 0.0714
# Number of batches:  126
# [Training] Epoch: 38 [DONE]
# [Validation] Epoch: 38 [DONE]
# [Epoch: 38, TrainLoss: 0.0262, TrainDice: 0.0025, ValLoss: 0.0815
# Number of batches:  126
# [Training] Epoch: 39 [DONE]
# [Validation] Epoch: 39 [DONE]
# [Epoch: 39, TrainLoss: 0.0258, TrainDice: 0.0025, ValLoss: 0.1040
# Number of batches:  126
# [Training] Epoch: 40 [DONE]
# [Validation] Epoch: 40 [DONE]
# [Epoch: 40, TrainLoss: 0.0253, TrainDice: 0.0024, ValLoss: 0.1077
# Number of batches:  126
# [Training] Epoch: 41 [DONE]
# [Validation] Epoch: 41 [DONE]
# [Epoch: 41, TrainLoss: 0.0251, TrainDice: 0.0024, ValLoss: 0.0682
# Number of batches:  126
# [Training] Epoch: 42 [DONE]
# [Validation] Epoch: 42 [DONE]
# [Epoch: 42, TrainLoss: 0.0246, TrainDice: 0.0023, ValLoss: 0.0783
# Number of batches:  126
# [Training] Epoch: 43 [DONE]
# [Validation] Epoch: 43 [DONE]
# [Epoch: 43, TrainLoss: 0.0235, TrainDice: 0.0022, ValLoss: 0.0765
# Number of batches:  126
# [Training] Epoch: 44 [DONE]
# [Validation] Epoch: 44 [DONE]
# [Epoch: 44, TrainLoss: 0.0246, TrainDice: 0.0024, ValLoss: 0.0646
# Number of batches:  126
# [Training] Epoch: 45 [DONE]
# [Validation] Epoch: 45 [DONE]
# [Epoch: 45, TrainLoss: 0.0234, TrainDice: 0.0023, ValLoss: 0.0564
# Number of batches:  126
# [Training] Epoch: 46 [DONE]
# [Validation] Epoch: 46 [DONE]
# [Epoch: 46, TrainLoss: 0.0224, TrainDice: 0.0021, ValLoss: 0.0492
# Number of batches:  126
# [Training] Epoch: 47 [DONE]
# [Validation] Epoch: 47 [DONE]
# [Epoch: 47, TrainLoss: 0.0225, TrainDice: 0.0022, ValLoss: 0.1105
# Number of batches:  126
# [Training] Epoch: 48 [DONE]
# [Validation] Epoch: 48 [DONE]
# [Epoch: 48, TrainLoss: 0.0226, TrainDice: 0.0022, ValLoss: 0.0947
# Number of batches:  126
# [Training] Epoch: 49 [DONE]
# [Validation] Epoch: 49 [DONE]
# [Epoch: 49, TrainLoss: 0.0222, TrainDice: 0.0021, ValLoss: 0.0491
# Number of batches:  126
# [Training] Epoch: 50 [DONE]
# [Validation] Epoch: 50 [DONE]
# [Epoch: 50, TrainLoss: 0.0214, TrainDice: 0.0020, ValLoss: 0.0472
# Number of batches:  126
# [Training] Epoch: 51 [DONE]
# [Validation] Epoch: 51 [DONE]
# [Epoch: 51, TrainLoss: 0.0222, TrainDice: 0.0021, ValLoss: 0.0469
# Number of batches:  126
# [Training] Epoch: 52 [DONE]
# [Validation] Epoch: 52 [DONE]
# [Epoch: 52, TrainLoss: 0.0220, TrainDice: 0.0021, ValLoss: 0.0439
# Number of batches:  126
# [Training] Epoch: 53 [DONE]
# [Validation] Epoch: 53 [DONE]
# [Epoch: 53, TrainLoss: 0.0210, TrainDice: 0.0020, ValLoss: 0.0991
# Number of batches:  126
# [Training] Epoch: 54 [DONE]
# [Validation] Epoch: 54 [DONE]
# [Epoch: 54, TrainLoss: 0.0210, TrainDice: 0.0020, ValLoss: 0.0614
# Number of batches:  126
# [Training] Epoch: 55 [DONE]
# [Validation] Epoch: 55 [DONE]
# [Epoch: 55, TrainLoss: 0.0208, TrainDice: 0.0020, ValLoss: 0.0456
# Number of batches:  126
# [Training] Epoch: 56 [DONE]
# [Validation] Epoch: 56 [DONE]
# [Epoch: 56, TrainLoss: 0.0200, TrainDice: 0.0019, ValLoss: 0.0651
# Number of batches:  126
# [Training] Epoch: 57 [DONE]
# [Validation] Epoch: 57 [DONE]
# [Epoch: 57, TrainLoss: 0.0205, TrainDice: 0.0020, ValLoss: 0.1268
# Number of batches:  126
# [Training] Epoch: 58 [DONE]
# [Validation] Epoch: 58 [DONE]
# [Epoch: 58, TrainLoss: 0.0216, TrainDice: 0.0020, ValLoss: 0.0652
# Number of batches:  126
# [Training] Epoch: 59 [DONE]
# [Validation] Epoch: 59 [DONE]
# [Epoch: 59, TrainLoss: 0.0206, TrainDice: 0.0020, ValLoss: 0.0656
# Number of batches:  126
# [Training] Epoch: 60 [DONE]
# [Validation] Epoch: 60 [DONE]
# [Epoch: 60, TrainLoss: 0.0208, TrainDice: 0.0020, ValLoss: 0.0663
# Number of batches:  126
# [Training] Epoch: 61 [DONE]
# [Validation] Epoch: 61 [DONE]
# [Epoch: 61, TrainLoss: 0.0199, TrainDice: 0.0019, ValLoss: 0.0495
# Number of batches:  126
# [Training] Epoch: 62 [DONE]
# [Validation] Epoch: 62 [DONE]
# [Epoch: 62, TrainLoss: 0.0195, TrainDice: 0.0019, ValLoss: 0.0684
# Number of batches:  126
# [Training] Epoch: 63 [DONE]
# [Validation] Epoch: 63 [DONE]
# [Epoch: 63, TrainLoss: 0.0198, TrainDice: 0.0019, ValLoss: 0.0736
# Number of batches:  126
# [Training] Epoch: 64 [DONE]
# [Validation] Epoch: 64 [DONE]
# [Epoch: 64, TrainLoss: 0.0201, TrainDice: 0.0019, ValLoss: 0.0599
# Number of batches:  126
# [Training] Epoch: 65 [DONE]
# [Validation] Epoch: 65 [DONE]
# [Epoch: 65, TrainLoss: 0.0184, TrainDice: 0.0018, ValLoss: 0.0615
# Number of batches:  126
# [Training] Epoch: 66 [DONE]
# [Validation] Epoch: 66 [DONE]
# [Epoch: 66, TrainLoss: 0.0188, TrainDice: 0.0018, ValLoss: 0.0501
# Number of batches:  126
# [Training] Epoch: 67 [DONE]
# [Validation] Epoch: 67 [DONE]
# [Epoch: 67, TrainLoss: 0.0185, TrainDice: 0.0018, ValLoss: 0.0886
# Number of batches:  126
# [Training] Epoch: 68 [DONE]
# [Validation] Epoch: 68 [DONE]
# [Epoch: 68, TrainLoss: 0.0185, TrainDice: 0.0018, ValLoss: 0.0532
# Number of batches:  126
# [Training] Epoch: 69 [DONE]
# [Validation] Epoch: 69 [DONE]
# [Epoch: 69, TrainLoss: 0.0189, TrainDice: 0.0018, ValLoss: 0.0561
# Number of batches:  126
# [Training] Epoch: 70 [DONE]
# [Validation] Epoch: 70 [DONE]
# [Epoch: 70, TrainLoss: 0.0183, TrainDice: 0.0018, ValLoss: 0.0671
# Number of batches:  126
# [Training] Epoch: 71 [DONE]
# [Validation] Epoch: 71 [DONE]
# [Epoch: 71, TrainLoss: 0.0186, TrainDice: 0.0018, ValLoss: 0.0522
# Number of batches:  126
# [Training] Epoch: 72 [DONE]
# [Validation] Epoch: 72 [DONE]
# [Epoch: 72, TrainLoss: 0.0188, TrainDice: 0.0018, ValLoss: 0.0598
# Number of batches:  126
# [Training] Epoch: 73 [DONE]
# [Validation] Epoch: 73 [DONE]
# [Epoch: 73, TrainLoss: 0.0182, TrainDice: 0.0018, ValLoss: 0.0604
# Number of batches:  126
# [Training] Epoch: 74 [DONE]
# [Validation] Epoch: 74 [DONE]
# [Epoch: 74, TrainLoss: 0.0189, TrainDice: 0.0018, ValLoss: 0.0647
# Number of batches:  126
# [Training] Epoch: 75 [DONE]
# [Validation] Epoch: 75 [DONE]
# [Epoch: 75, TrainLoss: 0.0173, TrainDice: 0.0017, ValLoss: 0.0833
# Number of batches:  126
# [Training] Epoch: 76 [DONE]
# [Validation] Epoch: 76 [DONE]
# [Epoch: 76, TrainLoss: 0.0179, TrainDice: 0.0017, ValLoss: 0.0579
# Number of batches:  126
# [Training] Epoch: 77 [DONE]
# [Validation] Epoch: 77 [DONE]
# [Epoch: 77, TrainLoss: 0.0182, TrainDice: 0.0017, ValLoss: 0.0370
# Number of batches:  126
# [Training] Epoch: 78 [DONE]
# [Validation] Epoch: 78 [DONE]
# [Epoch: 78, TrainLoss: 0.0180, TrainDice: 0.0017, ValLoss: 0.0439
# Number of batches:  126
# [Training] Epoch: 79 [DONE]
# [Validation] Epoch: 79 [DONE]
# [Epoch: 79, TrainLoss: 0.0169, TrainDice: 0.0016, ValLoss: 0.0661
# Number of batches:  126
# [Training] Epoch: 80 [DONE]
# [Validation] Epoch: 80 [DONE]
# [Epoch: 80, TrainLoss: 0.0170, TrainDice: 0.0016, ValLoss: 0.0614
# Number of batches:  126
# [Training] Epoch: 81 [DONE]
# [Validation] Epoch: 81 [DONE]
# [Epoch: 81, TrainLoss: 0.0173, TrainDice: 0.0016, ValLoss: 0.0513
# Number of batches:  126
# [Training] Epoch: 82 [DONE]
# [Validation] Epoch: 82 [DONE]
# [Epoch: 82, TrainLoss: 0.0178, TrainDice: 0.0017, ValLoss: 0.0667
# Number of batches:  126
# [Training] Epoch: 83 [DONE]
# [Validation] Epoch: 83 [DONE]
# [Epoch: 83, TrainLoss: 0.0172, TrainDice: 0.0017, ValLoss: 0.0501
# Number of batches:  126
# [Training] Epoch: 84 [DONE]
# [Validation] Epoch: 84 [DONE]
# [Epoch: 84, TrainLoss: 0.0178, TrainDice: 0.0017, ValLoss: 0.0575
# Number of batches:  126
# [Training] Epoch: 85 [DONE]
# [Validation] Epoch: 85 [DONE]
# [Epoch: 85, TrainLoss: 0.0172, TrainDice: 0.0017, ValLoss: 0.0497
# Number of batches:  126
# [Training] Epoch: 86 [DONE]
# [Validation] Epoch: 86 [DONE]
# [Epoch: 86, TrainLoss: 0.0178, TrainDice: 0.0017, ValLoss: 0.0498
# Number of batches:  126
# [Training] Epoch: 87 [DONE]
# [Validation] Epoch: 87 [DONE]
# [Epoch: 87, TrainLoss: 0.0166, TrainDice: 0.0016, ValLoss: 0.0459
# Number of batches:  126
# [Training] Epoch: 88 [DONE]
# [Validation] Epoch: 88 [DONE]
# [Epoch: 88, TrainLoss: 0.0172, TrainDice: 0.0016, ValLoss: 0.0542
# Number of batches:  126
# [Training] Epoch: 89 [DONE]
# [Validation] Epoch: 89 [DONE]
# [Epoch: 89, TrainLoss: 0.0165, TrainDice: 0.0016, ValLoss: 0.0505
# Number of batches:  126
# [Training] Epoch: 90 [DONE]
# [Validation] Epoch: 90 [DONE]
# [Epoch: 90, TrainLoss: 0.0168, TrainDice: 0.0016, ValLoss: 0.0436
# Number of batches:  126
# [Training] Epoch: 91 [DONE]
# [Validation] Epoch: 91 [DONE]
# [Epoch: 91, TrainLoss: 0.0160, TrainDice: 0.0015, ValLoss: 0.0574
# Number of batches:  126
# [Training] Epoch: 92 [DONE]
# [Validation] Epoch: 92 [DONE]
# [Epoch: 92, TrainLoss: 0.0158, TrainDice: 0.0015, ValLoss: 0.0419
# Number of batches:  126
# [Training] Epoch: 93 [DONE]
# [Validation] Epoch: 93 [DONE]
# [Epoch: 93, TrainLoss: 0.0160, TrainDice: 0.0015, ValLoss: 0.0619
# Number of batches:  126
# [Training] Epoch: 94 [DONE]
# [Validation] Epoch: 94 [DONE]
# [Epoch: 94, TrainLoss: 0.0160, TrainDice: 0.0015, ValLoss: 0.0667
# Number of batches:  126
# [Training] Epoch: 95 [DONE]
# [Validation] Epoch: 95 [DONE]
# [Epoch: 95, TrainLoss: 0.0162, TrainDice: 0.0015, ValLoss: 0.0389
# Number of batches:  126
# [Training] Epoch: 96 [DONE]
# [Validation] Epoch: 96 [DONE]
# [Epoch: 96, TrainLoss: 0.0162, TrainDice: 0.0016, ValLoss: 0.0565
# Number of batches:  126
# [Training] Epoch: 97 [DONE]
# [Validation] Epoch: 97 [DONE]
# [Epoch: 97, TrainLoss: 0.0169, TrainDice: 0.0016, ValLoss: 0.0342
# Number of batches:  126
# [Training] Epoch: 98 [DONE]
# [Validation] Epoch: 98 [DONE]
# [Epoch: 98, TrainLoss: 0.0158, TrainDice: 0.0015, ValLoss: 0.0738
# Number of batches:  126
# [Training] Epoch: 99 [DONE]
# [Validation] Epoch: 99 [DONE]
# [Epoch: 99, TrainLoss: 0.0159, TrainDice: 0.0015, ValLoss: 0.0351
# Number of batches:  126
# [Training] Epoch: 100 [DONE]
# [Validation] Epoch: 100 [DONE]
# [Epoch: 100, TrainLoss: 0.0171, TrainDice: 0.0016, ValLoss: 0.0547
# Number of batches:  126
# [Training] Epoch: 101 [DONE]
# [Validation] Epoch: 101 [DONE]
# [Epoch: 101, TrainLoss: 0.0159, TrainDice: 0.0015, ValLoss: 0.0493
# Number of batches:  126
# [Training] Epoch: 102 [DONE]
# [Validation] Epoch: 102 [DONE]
# [Epoch: 102, TrainLoss: 0.0154, TrainDice: 0.0015, ValLoss: 0.0673
# Number of batches:  126
# [Training] Epoch: 103 [DONE]
# [Validation] Epoch: 103 [DONE]
# [Epoch: 103, TrainLoss: 0.0154, TrainDice: 0.0015, ValLoss: 0.0695
# Number of batches:  126
# [Training] Epoch: 104 [DONE]
# [Validation] Epoch: 104 [DONE]
# [Epoch: 104, TrainLoss: 0.0155, TrainDice: 0.0015, ValLoss: 0.0699
# Number of batches:  126
# [Training] Epoch: 105 [DONE]
# [Validation] Epoch: 105 [DONE]
# [Epoch: 105, TrainLoss: 0.0155, TrainDice: 0.0015, ValLoss: 0.0505
# Number of batches:  126
# [Training] Epoch: 106 [DONE]
# [Validation] Epoch: 106 [DONE]
# [Epoch: 106, TrainLoss: 0.0158, TrainDice: 0.0015, ValLoss: 0.0532
# Number of batches:  126
# [Training] Epoch: 107 [DONE]
# [Validation] Epoch: 107 [DONE]
# [Epoch: 107, TrainLoss: 0.0147, TrainDice: 0.0014, ValLoss: 0.0656
# Number of batches:  126
# [Training] Epoch: 108 [DONE]
# [Validation] Epoch: 108 [DONE]
# [Epoch: 108, TrainLoss: 0.0152, TrainDice: 0.0015, ValLoss: 0.0687
# Number of batches:  126
# [Training] Epoch: 109 [DONE]
# [Validation] Epoch: 109 [DONE]
# [Epoch: 109, TrainLoss: 0.0153, TrainDice: 0.0015, ValLoss: 0.0699
# Number of batches:  126
# [Training] Epoch: 110 [DONE]
# [Validation] Epoch: 110 [DONE]
# [Epoch: 110, TrainLoss: 0.0147, TrainDice: 0.0014, ValLoss: 0.0468
# Number of batches:  126
# [Training] Epoch: 111 [DONE]
# [Validation] Epoch: 111 [DONE]
# [Epoch: 111, TrainLoss: 0.0148, TrainDice: 0.0014, ValLoss: 0.0441
# Number of batches:  126
# [Training] Epoch: 112 [DONE]
# [Validation] Epoch: 112 [DONE]
# [Epoch: 112, TrainLoss: 0.0149, TrainDice: 0.0014, ValLoss: 0.0396
# Number of batches:  126
# [Training] Epoch: 113 [DONE]
# [Validation] Epoch: 113 [DONE]
# [Epoch: 113, TrainLoss: 0.0158, TrainDice: 0.0015, ValLoss: 0.0467
# Number of batches:  126
# [Training] Epoch: 114 [DONE]
# [Validation] Epoch: 114 [DONE]
# [Epoch: 114, TrainLoss: 0.0153, TrainDice: 0.0015, ValLoss: 0.0468
# Number of batches:  126
# [Training] Epoch: 115 [DONE]
# [Validation] Epoch: 115 [DONE]
# [Epoch: 115, TrainLoss: 0.0154, TrainDice: 0.0015, ValLoss: 0.0517
# Number of batches:  126
# [Training] Epoch: 116 [DONE]
# [Validation] Epoch: 116 [DONE]
# [Epoch: 116, TrainLoss: 0.0149, TrainDice: 0.0014, ValLoss: 0.0619
# Number of batches:  126
# [Training] Epoch: 117 [DONE]
# [Validation] Epoch: 117 [DONE]
# [Epoch: 117, TrainLoss: 0.0149, TrainDice: 0.0014, ValLoss: 0.0499
# Number of batches:  126
# [Training] Epoch: 118 [DONE]
# [Validation] Epoch: 118 [DONE]
# [Epoch: 118, TrainLoss: 0.0143, TrainDice: 0.0014, ValLoss: 0.0354
# Number of batches:  126
# [Training] Epoch: 119 [DONE]
# [Validation] Epoch: 119 [DONE]
# [Epoch: 119, TrainLoss: 0.0151, TrainDice: 0.0014, ValLoss: 0.0635
# Number of batches:  126
# [Training] Epoch: 120 [DONE]
# [Validation] Epoch: 120 [DONE]
# [Epoch: 120, TrainLoss: 0.0151, TrainDice: 0.0014, ValLoss: 0.0408
# Number of batches:  126
# [Training] Epoch: 121 [DONE]
# [Validation] Epoch: 121 [DONE]
# [Epoch: 121, TrainLoss: 0.0146, TrainDice: 0.0014, ValLoss: 0.0620
# Number of batches:  126
# [Training] Epoch: 122 [DONE]
# [Validation] Epoch: 122 [DONE]
# [Epoch: 122, TrainLoss: 0.0147, TrainDice: 0.0014, ValLoss: 0.0400
# Number of batches:  126
# [Training] Epoch: 123 [DONE]
# [Validation] Epoch: 123 [DONE]
# [Epoch: 123, TrainLoss: 0.0146, TrainDice: 0.0014, ValLoss: 0.0387
# Number of batches:  126
# [Training] Epoch: 124 [DONE]
# [Validation] Epoch: 124 [DONE]
# [Epoch: 124, TrainLoss: 0.0134, TrainDice: 0.0013, ValLoss: 0.0732
# Number of batches:  126
# [Training] Epoch: 125 [DONE]
# [Validation] Epoch: 125 [DONE]
# [Epoch: 125, TrainLoss: 0.0147, TrainDice: 0.0014, ValLoss: 0.0898
# Number of batches:  126
# [Training] Epoch: 126 [DONE]
# [Validation] Epoch: 126 [DONE]
# [Epoch: 126, TrainLoss: 0.0150, TrainDice: 0.0014, ValLoss: 0.0511
# Number of batches:  126
# [Training] Epoch: 127 [DONE]
# [Validation] Epoch: 127 [DONE]
# [Epoch: 127, TrainLoss: 0.0145, TrainDice: 0.0014, ValLoss: 0.0354
# Number of batches:  126
# [Training] Epoch: 128 [DONE]
# [Validation] Epoch: 128 [DONE]
# [Epoch: 128, TrainLoss: 0.0144, TrainDice: 0.0014, ValLoss: 0.0462
# Number of batches:  126
# [Training] Epoch: 129 [DONE]
# [Validation] Epoch: 129 [DONE]
# [Epoch: 129, TrainLoss: 0.0147, TrainDice: 0.0014, ValLoss: 0.0358
# Number of batches:  126
# [Training] Epoch: 130 [DONE]
# [Validation] Epoch: 130 [DONE]
# [Epoch: 130, TrainLoss: 0.0143, TrainDice: 0.0014, ValLoss: 0.0370
# Number of batches:  126
# [Training] Epoch: 131 [DONE]
# [Validation] Epoch: 131 [DONE]
# [Epoch: 131, TrainLoss: 0.0137, TrainDice: 0.0013, ValLoss: 0.0422
# Number of batches:  126
# [Training] Epoch: 132 [DONE]
# [Validation] Epoch: 132 [DONE]
# [Epoch: 132, TrainLoss: 0.0138, TrainDice: 0.0013, ValLoss: 0.0634
# Number of batches:  126
# [Training] Epoch: 133 [DONE]
# [Validation] Epoch: 133 [DONE]
# [Epoch: 133, TrainLoss: 0.0142, TrainDice: 0.0014, ValLoss: 0.0375
# Number of batches:  126
# [Training] Epoch: 134 [DONE]
# [Validation] Epoch: 134 [DONE]
# [Epoch: 134, TrainLoss: 0.0146, TrainDice: 0.0014, ValLoss: 0.0353
# Number of batches:  126
# [Training] Epoch: 135 [DONE]
# [Validation] Epoch: 135 [DONE]
# [Epoch: 135, TrainLoss: 0.0148, TrainDice: 0.0014, ValLoss: 0.0417
# Number of batches:  126
# [Training] Epoch: 136 [DONE]
# [Validation] Epoch: 136 [DONE]
# [Epoch: 136, TrainLoss: 0.0143, TrainDice: 0.0014, ValLoss: 0.0449
# Number of batches:  126
# [Training] Epoch: 137 [DONE]
# [Validation] Epoch: 137 [DONE]
# [Epoch: 137, TrainLoss: 0.0139, TrainDice: 0.0013, ValLoss: 0.0727
# Number of batches:  126
# [Training] Epoch: 138 [DONE]
# [Validation] Epoch: 138 [DONE]
# [Epoch: 138, TrainLoss: 0.0143, TrainDice: 0.0014, ValLoss: 0.0657
# Number of batches:  126
# [Training] Epoch: 139 [DONE]
# [Validation] Epoch: 139 [DONE]
# [Epoch: 139, TrainLoss: 0.0144, TrainDice: 0.0014, ValLoss: 0.0442
# Number of batches:  126
# [Training] Epoch: 140 [DONE]
# [Validation] Epoch: 140 [DONE]
# [Epoch: 140, TrainLoss: 0.0131, TrainDice: 0.0012, ValLoss: 0.0458
# Number of batches:  126
# [Training] Epoch: 141 [DONE]
# [Validation] Epoch: 141 [DONE]
# [Epoch: 141, TrainLoss: 0.0136, TrainDice: 0.0013, ValLoss: 0.0807
# Number of batches:  126
# [Training] Epoch: 142 [DONE]
# [Validation] Epoch: 142 [DONE]
# [Epoch: 142, TrainLoss: 0.0133, TrainDice: 0.0013, ValLoss: 0.0598
# Number of batches:  126
# [Training] Epoch: 143 [DONE]
# [Validation] Epoch: 143 [DONE]
# [Epoch: 143, TrainLoss: 0.0139, TrainDice: 0.0013, ValLoss: 0.0430
# Number of batches:  126
# [Training] Epoch: 144 [DONE]
# [Validation] Epoch: 144 [DONE]
# [Epoch: 144, TrainLoss: 0.0133, TrainDice: 0.0013, ValLoss: 0.0427
# Number of batches:  126
# [Training] Epoch: 145 [DONE]
# [Validation] Epoch: 145 [DONE]
# [Epoch: 145, TrainLoss: 0.0135, TrainDice: 0.0013, ValLoss: 0.0353
# Number of batches:  126
# [Training] Epoch: 146 [DONE]
# [Validation] Epoch: 146 [DONE]
# [Epoch: 146, TrainLoss: 0.0141, TrainDice: 0.0013, ValLoss: 0.0697
# Number of batches:  126
# [Training] Epoch: 147 [DONE]
# [Validation] Epoch: 147 [DONE]
# [Epoch: 147, TrainLoss: 0.0142, TrainDice: 0.0014, ValLoss: 0.0432
# Number of batches:  126
# [Training] Epoch: 148 [DONE]
# [Validation] Epoch: 148 [DONE]
# [Epoch: 148, TrainLoss: 0.0135, TrainDice: 0.0013, ValLoss: 0.0555
# Number of batches:  126
# [Training] Epoch: 149 [DONE]
# [Validation] Epoch: 149 [DONE]
# [Epoch: 149, TrainLoss: 0.0139, TrainDice: 0.0013, ValLoss: 0.0458
