# %% [markdown]
# # Project MTI865 - Heart segmentation using UNet
#
# ---
#
# # Model training - Dice loss and CE Loss
#
# $$
# \mathcal{L} = w_{CE} \mathcal{L}_{CE} + w_{DSC} \mathcal{L}_{DSC}
# $$

# %%
# adding .. to path 
import sys 
sys.path.append('..')

# %%
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision.transforms import v2
from progressBar import printProgressBar

import medicalDataLoader
import argparse
import utils

from UNet_Base import *
import random
import torch
import pdb
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Parameters 
batch_size = 8
batch_size_val = 4
lr =  0.003   # Learning Rate
total_epochs = 120  # Number of epochs
weight_decay = 1e-5
ce_loss_weight = 0.7 # Cross Entropy Loss Weight proportion
dice_loss_weight = 0.3 # Dice Loss Weight proportion 
param_dict = {
    "batch_size": batch_size,
    "lr": lr,
    "total_epochs": total_epochs,
    "weight_decay": weight_decay,
    "ce_loss_weight": ce_loss_weight,
    "dice_loss_weight": dice_loss_weight
}

modelName = f"DSC-CE-UNet-{lr}-{total_epochs}-{ce_loss_weight}-{dice_loss_weight}"
model_dir = f"models/{modelName}"
# write params in a file 

os.makedirs(model_dir, exist_ok=True)
with open(f"{model_dir}/params.txt", 'w') as f:
    print(param_dict, file=f)

print(f"Parameters saved to {model_dir}/params.txt")

# %%
# Define image and mask transformations
transform = v2.Compose([
    v2.ToTensor(),
    v2.Normalize(mean=[0.137], std=[0.1733]) # Normalisation values for the training set (mean and std) 
])

mask_transform = v2.Compose([
    v2.ToTensor(),
])

# %%
# Define dataloaders
root_dir = './data/'
print(' Dataset: {} '.format(root_dir))

train_set_full = medicalDataLoader.MedicalImageDataset('train',
                                                    root_dir,
                                                    transform=transform,
                                                    mask_transform=mask_transform,
                                                    augment=True,
                                                    equalize=False)

train_loader_full = DataLoader(train_set_full,
                            batch_size=batch_size,
                            worker_init_fn=np.random.seed(0),
                            num_workers=0,
                            shuffle=True)


val_set = medicalDataLoader.MedicalImageDataset('val',
                                                root_dir,
                                                transform=transform,
                                                mask_transform=mask_transform,
                                                equalize=False)

val_loader = DataLoader(val_set,
                        batch_size=batch_size_val,
                        worker_init_fn=np.random.seed(0),
                        num_workers=0,
                        shuffle=False)
# Out:
#  Dataset: ./data/
# Found 204 items in train
# First item:  ('./data/train\\Img\\patient006_01_1.png', './data/train\\GT\\patient006_01_1.png')
# Found 74 items in val
# First item:  ('./data/val\\Img\\patient001_01_1.png', './data/val\\GT\\patient001_01_1.png')

# %%
def runTraining(writer: SummaryWriter):
    print("-" * 40)
    print("~~~~~~~~  Starting the training... ~~~~~~")
    print("-" * 40)

    num_classes = 4

    # Set device depending on the availability of GPU
    if torch.cuda.is_available():
        device = torch.device("cuda")
    # elif torch.mps.is_available():  # Apple M-series of chips
    #     device = torch.device("mps")
    else:
        device = torch.device("cpu")

    print(f"Using device: {device}")

    print("~~~~~~~~~~~ Creating the UNet model ~~~~~~~~~~")
    print(" Model Name: {}".format(modelName))

    ## CREATION OF YOUR MODEL
    net = UNet(num_classes).to(device)

    print(
        "Total params: {0:,}".format(
            sum(p.numel() for p in net.parameters() if p.requires_grad)
        )
    )

    # DEFINE YOUR OUTPUT COMPONENTS (e.g., SOFTMAX, LOSS FUNCTION, ETC)
    CE_loss = torch.nn.CrossEntropyLoss().to(device)



    ## PUT EVERYTHING IN GPU RESOURCES
    if torch.cuda.is_available():
        net.cuda()
        CE_loss.cuda()
        

    ## DEFINE YOUR OPTIMIZER
    optimizer = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)

    ### To save statistics ####
    train_losses = []
    train_dc_losses = []
    val_losses = []
    # val_dc_losses = []

    best_loss_val = 1000

    directory = "Results/Statistics/" + modelName

    print("~~~~~~~~~~~ Starting the training ~~~~~~~~~~")
    if os.path.exists(directory) == False:
        os.makedirs(directory)

    ## START THE TRAINING

    ## FOR EACH EPOCH
    for epoch in range(total_epochs):
        net.train()

        num_batches = len(train_loader_full)
        print("Number of batches: ", num_batches)

        running_train_loss = 0
        running_dice_loss = 0

        # Training loop
        for idx, data in enumerate(train_loader_full):
            ### Set to zero all the gradients
            net.zero_grad()
            optimizer.zero_grad()

            ## GET IMAGES, LABELS and IMG NAMES
            images, labels, img_names = data

            ### From numpy to torch variables
            labels = utils.to_var(labels).to(device)
            images = utils.to_var(images).to(device)

            # Forward pass
            net_predictions = net(images) # Predictions have shape [batch_size, num_classes, height, width]

            # Get the segmentation classes
            segmentation_classes = utils.getTargetSegmentation(labels)
            # Modify segmentation classes to be one-hot encoded (shape [batch_size, num_classes, height, width])
            dice_target = F.one_hot(segmentation_classes, num_classes = num_classes).permute(0,3,1,2).contiguous()

            # Compute the loss
            loss_ce = ce_loss_weight * CE_loss(net_predictions, segmentation_classes)
            loss_dice = dice_loss_weight * DiceLoss()(net_predictions, dice_target)
            loss = loss_ce + loss_dice

            running_train_loss += loss.item()
            # dice_loss = dice_coefficient(net_predictions, labels)
            # dice_loss = utils.compute_dsc(net_predictions, labels)
            # running_dice_loss += dice_loss

            # Backprop
            loss.backward()
            optimizer.step()

            # Add the loss to the tensorboard every 5 batches
            if idx % 10 == 0:
                writer.add_scalar(
                    "Loss/train", running_train_loss / (idx + 1), epoch * len(train_loader_full) + idx
                )

            if idx % 100 == 0:
                # Also add visualizations of the images
                probs = torch.softmax(net_predictions, dim=1)
                y_pred = torch.argmax(probs, dim=1)
                writer.add_figure(f'predictions vs. actuals for {modelName}',
                            utils.plot_net_predictions(images, labels, y_pred, batch_size),
                            global_step=epoch * len(train_loader_full) + idx)

            # THIS IS JUST TO VISUALIZE THE TRAINING
            printProgressBar(
                idx + 1,
                num_batches,
                prefix="[Training] Epoch: {} ".format(epoch),
                length=15,
                suffix=" Loss: {:.4f}, ".format(running_train_loss / (idx + 1)),
            )

        train_loss = running_train_loss / num_batches
        train_losses.append(train_loss)

        train_dc_loss = running_dice_loss / num_batches
        train_dc_losses.append(train_dc_loss)

        net.eval()
        val_running_loss = 0
        val_running_dc = 0

        # Validation loop
        with torch.no_grad():
            for idx, data in enumerate(val_loader):
                images, labels, img_names = data

                labels = utils.to_var(labels).to(device)
                images = utils.to_var(images).to(device)

                net_predictions = net(images)

                segmentation_classes = utils.getTargetSegmentation(labels)
                dice_target = F.one_hot(segmentation_classes, num_classes = num_classes).permute(0,3,1,2).contiguous()

                loss_ce = ce_loss_weight * CE_loss(net_predictions, segmentation_classes)
                loss_dice = dice_loss_weight * DiceLoss()(net_predictions, dice_target)
                loss = loss_ce + loss_dice

                val_running_loss += loss.item()
                # dice_loss = dice_coefficient(net_predictions, labels)
                # dice_loss = utils.compute_dsc(net_predictions, labels)
                # val_running_dc += dice_loss

                if idx % 10 == 0:
                    writer.add_scalar(
                        "Loss/val",
                        val_running_loss / (idx + 1),
                        epoch * len(val_loader) + idx,
                    )

                printProgressBar(
                    idx + 1,
                    len(val_loader),
                    prefix="[Validation] Epoch: {} ".format(epoch),
                    length=15,
                    suffix=" Loss: {:.4f}, ".format(val_running_loss / (idx + 1)),
                )

        val_loss = val_running_loss / len(val_loader)
        val_losses.append(val_loss)
        # dc_loss = val_running_dc / len(val_loader)
        # val_dc_losses.append(dc_loss)

        # Check if model performed best and save it if true
        if val_loss < best_loss_val:
            best_loss_val = val_loss
            if not os.path.exists("./models/" + modelName):
                os.makedirs("./models/" + modelName)
            torch.save(
                net.state_dict(), "./models/" + modelName + "/" + str(epoch) + "_Epoch"
            )
        
        printProgressBar(
            num_batches,
            num_batches,
            done="[Epoch: {}, TrainLoss: {:.4f}, TrainDice: {:.4f}, ValLoss: {:.4f}".format(
                epoch, train_loss, train_dc_loss, val_loss
            ),
        )

        # Check if loss has not decreased for 10 epochs
        # if epoch > 10 and val_losses[-1] > val_losses[-10]:
        #     print("Stopping early as validation loss has not decreased for 10 epochs")
        #     break

        np.save(os.path.join(directory, "Losses.npy"), train_losses)
    writer.flush()  # Flush the writer to ensure that all the data is written to disk

# %%
# Set up Tensorboard writer
writer = SummaryWriter()
runTraining(writer)
writer.close()
# Out:
# ----------------------------------------
# ~~~~~~~~  Starting the training... ~~~~~~
# ----------------------------------------
# Using device: cpu
# ~~~~~~~~~~~ Creating the UNet model ~~~~~~~~~~
#  Model Name: DSC-CE-UNet-0.003-120-0.7-0.3
# Total params: 60,664
# ~~~~~~~~~~~ Starting the training ~~~~~~~~~~
# Number of batches:  26
# [Training] Epoch: 0 [DONE]
# [Validation] Epoch: 0 [DONE]
# [Epoch: 0, TrainLoss: 1.0556, TrainDice: 0.0000, ValLoss: 0.8890
# Number of batches:  26
# [Training] Epoch: 1 [DONE]
# [Validation] Epoch: 1 [DONE]
# [Epoch: 1, TrainLoss: 0.7220, TrainDice: 0.0000, ValLoss: 0.5998
# Number of batches:  26
# [Training] Epoch: 2 [DONE]
# [Validation] Epoch: 2 [DONE]
# [Epoch: 2, TrainLoss: 0.4782, TrainDice: 0.0000, ValLoss: 0.3090
# Number of batches:  26
# [Training] Epoch: 3 [DONE]
# [Validation] Epoch: 3 [DONE]
# [Epoch: 3, TrainLoss: 0.3271, TrainDice: 0.0000, ValLoss: 0.2395
# Number of batches:  26
# [Training] Epoch: 4 [DONE]
# [Validation] Epoch: 4 [DONE]
# [Epoch: 4, TrainLoss: 0.2393, TrainDice: 0.0000, ValLoss: 0.1870
# Number of batches:  26
# [Training] Epoch: 5 [DONE]
# [Validation] Epoch: 5 [DONE]
# [Epoch: 5, TrainLoss: 0.1848, TrainDice: 0.0000, ValLoss: 0.1599
# Number of batches:  26
# [Training] Epoch: 6 [DONE]
# [Validation] Epoch: 6 [DONE]
# [Epoch: 6, TrainLoss: 0.1423, TrainDice: 0.0000, ValLoss: 0.1401
# Number of batches:  26
# [Training] Epoch: 7 [DONE]
# [Validation] Epoch: 7 [DONE]
# [Epoch: 7, TrainLoss: 0.1189, TrainDice: 0.0000, ValLoss: 0.1088
# Number of batches:  26
# [Training] Epoch: 8 [DONE]
# [Validation] Epoch: 8 [DONE]
# [Epoch: 8, TrainLoss: 0.1026, TrainDice: 0.0000, ValLoss: 0.0989
# Number of batches:  26
# [Training] Epoch: 9 [DONE]
# [Validation] Epoch: 9 [DONE]
# [Epoch: 9, TrainLoss: 0.0895, TrainDice: 0.0000, ValLoss: 0.0904
# Number of batches:  26
# [Training] Epoch: 10 [DONE]
# [Validation] Epoch: 10 [DONE]
# [Epoch: 10, TrainLoss: 0.0798, TrainDice: 0.0000, ValLoss: 0.0828
# Number of batches:  26
# [Training] Epoch: 11 [DONE]
# [Validation] Epoch: 11 [DONE]
# [Epoch: 11, TrainLoss: 0.0746, TrainDice: 0.0000, ValLoss: 0.0831
# Number of batches:  26
# [Training] Epoch: 12 [DONE]
# [Validation] Epoch: 12 [DONE]
# [Epoch: 12, TrainLoss: 0.0713, TrainDice: 0.0000, ValLoss: 0.0947
# Number of batches:  26
# [Training] Epoch: 13 [DONE]
# [Validation] Epoch: 13 [DONE]
# [Epoch: 13, TrainLoss: 0.0679, TrainDice: 0.0000, ValLoss: 0.0785
# Number of batches:  26
# [Training] Epoch: 14 [DONE]
# [Validation] Epoch: 14 [DONE]
# [Epoch: 14, TrainLoss: 0.0652, TrainDice: 0.0000, ValLoss: 0.0997
# Number of batches:  26
# [Training] Epoch: 15 [DONE]
# [Validation] Epoch: 15 [DONE]
# [Epoch: 15, TrainLoss: 0.0605, TrainDice: 0.0000, ValLoss: 0.0821
# Number of batches:  26
# [Training] Epoch: 16 [DONE]
# [Validation] Epoch: 16 [DONE]
# [Epoch: 16, TrainLoss: 0.0593, TrainDice: 0.0000, ValLoss: 0.0661
# Number of batches:  26
# [Training] Epoch: 17 [DONE]
# [Validation] Epoch: 17 [DONE]
# [Epoch: 17, TrainLoss: 0.0567, TrainDice: 0.0000, ValLoss: 0.0839
# Number of batches:  26
# [Training] Epoch: 18 [DONE]
# [Validation] Epoch: 18 [DONE]
# [Epoch: 18, TrainLoss: 0.0558, TrainDice: 0.0000, ValLoss: 0.0643
# Number of batches:  26
# [Training] Epoch: 19 [DONE]
# [Validation] Epoch: 19 [DONE]
# [Epoch: 19, TrainLoss: 0.0549, TrainDice: 0.0000, ValLoss: 0.0703
# Number of batches:  26
# [Training] Epoch: 20 [DONE]
# [Validation] Epoch: 20 [DONE]
# [Epoch: 20, TrainLoss: 0.0543, TrainDice: 0.0000, ValLoss: 0.0703
# Number of batches:  26
# [Training] Epoch: 21 [DONE]
# [Validation] Epoch: 21 [DONE]
# [Epoch: 21, TrainLoss: 0.0534, TrainDice: 0.0000, ValLoss: 0.0725
# Number of batches:  26
# [Training] Epoch: 22 [DONE]
# [Validation] Epoch: 22 [DONE]
# [Epoch: 22, TrainLoss: 0.0523, TrainDice: 0.0000, ValLoss: 0.0835
# Number of batches:  26
# [Training] Epoch: 23 [DONE]
# [Validation] Epoch: 23 [DONE]
# [Epoch: 23, TrainLoss: 0.0531, TrainDice: 0.0000, ValLoss: 0.0630
# Number of batches:  26
# [Training] Epoch: 24 [DONE]
# [Validation] Epoch: 24 [DONE]
# [Epoch: 24, TrainLoss: 0.0516, TrainDice: 0.0000, ValLoss: 0.0973
# Number of batches:  26
# [Training] Epoch: 25 [DONE]
# [Validation] Epoch: 25 [DONE]
# [Epoch: 25, TrainLoss: 0.0513, TrainDice: 0.0000, ValLoss: 0.0602
# Number of batches:  26
# [Training] Epoch: 26 [DONE]
# [Validation] Epoch: 26 [DONE]
# [Epoch: 26, TrainLoss: 0.0499, TrainDice: 0.0000, ValLoss: 0.0644
# Number of batches:  26
# [Training] Epoch: 27 [DONE]
# [Validation] Epoch: 27 [DONE]
# [Epoch: 27, TrainLoss: 0.0502, TrainDice: 0.0000, ValLoss: 0.0586
# Number of batches:  26
# [Training] Epoch: 28 [DONE]
# [Validation] Epoch: 28 [DONE]
# [Epoch: 28, TrainLoss: 0.0489, TrainDice: 0.0000, ValLoss: 0.0572
# Number of batches:  26
# [Training] Epoch: 29 [DONE]
# [Validation] Epoch: 29 [DONE]
# [Epoch: 29, TrainLoss: 0.0480, TrainDice: 0.0000, ValLoss: 0.0615
# Number of batches:  26
# [Training] Epoch: 30 [DONE]
# [Validation] Epoch: 30 [DONE]
# [Epoch: 30, TrainLoss: 0.0484, TrainDice: 0.0000, ValLoss: 0.0616
# Number of batches:  26
# [Training] Epoch: 31 [DONE]
# [Validation] Epoch: 31 [DONE]
# [Epoch: 31, TrainLoss: 0.0481, TrainDice: 0.0000, ValLoss: 0.0547
# Number of batches:  26
# [Training] Epoch: 32 [DONE]
# [Validation] Epoch: 32 [DONE]
# [Epoch: 32, TrainLoss: 0.0501, TrainDice: 0.0000, ValLoss: 0.0858
# Number of batches:  26
# [Training] Epoch: 33 [DONE]
# [Validation] Epoch: 33 [DONE]
# [Epoch: 33, TrainLoss: 0.0487, TrainDice: 0.0000, ValLoss: 0.0629
# Number of batches:  26
# [Training] Epoch: 34 [DONE]
# [Validation] Epoch: 34 [DONE]
# [Epoch: 34, TrainLoss: 0.0476, TrainDice: 0.0000, ValLoss: 0.0592
# Number of batches:  26
# [Training] Epoch: 35 [DONE]
# [Validation] Epoch: 35 [DONE]
# [Epoch: 35, TrainLoss: 0.0467, TrainDice: 0.0000, ValLoss: 0.0564
# Number of batches:  26
# [Training] Epoch: 36 [DONE]
# [Validation] Epoch: 36 [DONE]
# [Epoch: 36, TrainLoss: 0.0467, TrainDice: 0.0000, ValLoss: 0.0660
# Number of batches:  26
# [Training] Epoch: 37 [DONE]
# [Validation] Epoch: 37 [DONE]
# [Epoch: 37, TrainLoss: 0.0468, TrainDice: 0.0000, ValLoss: 0.0541
# Number of batches:  26
# [Training] Epoch: 38 [DONE]
# [Validation] Epoch: 38 [DONE]
# [Epoch: 38, TrainLoss: 0.0463, TrainDice: 0.0000, ValLoss: 0.0708
# Number of batches:  26
# [Training] Epoch: 39 [DONE]
# [Validation] Epoch: 39 [DONE]
# [Epoch: 39, TrainLoss: 0.0465, TrainDice: 0.0000, ValLoss: 0.0658
# Number of batches:  26
# [Training] Epoch: 40 [DONE]
# [Validation] Epoch: 40 [DONE]
# [Epoch: 40, TrainLoss: 0.0462, TrainDice: 0.0000, ValLoss: 0.0746
# Number of batches:  26
# [Training] Epoch: 41 [DONE]
# [Validation] Epoch: 41 [DONE]
# [Epoch: 41, TrainLoss: 0.0460, TrainDice: 0.0000, ValLoss: 0.0581
# Number of batches:  26
# [Training] Epoch: 42 [DONE]
# [Validation] Epoch: 42 [DONE]
# [Epoch: 42, TrainLoss: 0.0451, TrainDice: 0.0000, ValLoss: 0.0720
# Number of batches:  26
# [Training] Epoch: 43 [DONE]
# [Validation] Epoch: 43 [DONE]
# [Epoch: 43, TrainLoss: 0.0453, TrainDice: 0.0000, ValLoss: 0.0528
# Number of batches:  26
# [Training] Epoch: 44 [DONE]
# [Validation] Epoch: 44 [DONE]
# [Epoch: 44, TrainLoss: 0.0455, TrainDice: 0.0000, ValLoss: 0.0553
# Number of batches:  26
# [Training] Epoch: 45 [DONE]
# [Validation] Epoch: 45 [DONE]
# [Epoch: 45, TrainLoss: 0.0450, TrainDice: 0.0000, ValLoss: 0.0627
# Number of batches:  26
# [Training] Epoch: 46 [DONE]
# [Validation] Epoch: 46 [DONE]
# [Epoch: 46, TrainLoss: 0.0439, TrainDice: 0.0000, ValLoss: 0.0667
# Number of batches:  26
# [Training] Epoch: 47 [DONE]
# [Validation] Epoch: 47 [DONE]
# [Epoch: 47, TrainLoss: 0.0441, TrainDice: 0.0000, ValLoss: 0.0656
# Number of batches:  26
# [Training] Epoch: 48 [DONE]
# [Validation] Epoch: 48 [DONE]
# [Epoch: 48, TrainLoss: 0.0442, TrainDice: 0.0000, ValLoss: 0.0504
# Number of batches:  26
# [Training] Epoch: 49 [DONE]
# [Validation] Epoch: 49 [DONE]
# [Epoch: 49, TrainLoss: 0.0435, TrainDice: 0.0000, ValLoss: 0.0842
# Number of batches:  26
# [Training] Epoch: 50 [DONE]
# [Validation] Epoch: 50 [DONE]
# [Epoch: 50, TrainLoss: 0.0444, TrainDice: 0.0000, ValLoss: 0.0641
# Number of batches:  26
# [Training] Epoch: 51 [DONE]
# [Validation] Epoch: 51 [DONE]
# [Epoch: 51, TrainLoss: 0.0437, TrainDice: 0.0000, ValLoss: 0.0550
# Number of batches:  26
# [Training] Epoch: 52 [DONE]
# [Validation] Epoch: 52 [DONE]
# [Epoch: 52, TrainLoss: 0.0430, TrainDice: 0.0000, ValLoss: 0.0650
# Number of batches:  26
# [Training] Epoch: 53 [DONE]
# [Validation] Epoch: 53 [DONE]
# [Epoch: 53, TrainLoss: 0.0426, TrainDice: 0.0000, ValLoss: 0.0571
# Number of batches:  26
# [Training] Epoch: 54 [DONE]
# [Validation] Epoch: 54 [DONE]
# [Epoch: 54, TrainLoss: 0.0430, TrainDice: 0.0000, ValLoss: 0.0834
# Number of batches:  26
# [Training] Epoch: 55 [DONE]
# [Validation] Epoch: 55 [DONE]
# [Epoch: 55, TrainLoss: 0.0441, TrainDice: 0.0000, ValLoss: 0.0567
# Number of batches:  26
# [Training] Epoch: 56 [DONE]
# [Validation] Epoch: 56 [DONE]
# [Epoch: 56, TrainLoss: 0.0430, TrainDice: 0.0000, ValLoss: 0.0534
# Number of batches:  26
# [Training] Epoch: 57 [DONE]
# [Validation] Epoch: 57 [DONE]
# [Epoch: 57, TrainLoss: 0.0431, TrainDice: 0.0000, ValLoss: 0.0677
# Number of batches:  26
# [Training] Epoch: 58 [DONE]
# [Validation] Epoch: 58 [DONE]
# [Epoch: 58, TrainLoss: 0.0433, TrainDice: 0.0000, ValLoss: 0.0586
# Number of batches:  26
# [Training] Epoch: 59 [DONE]
# [Validation] Epoch: 59 [DONE]
# [Epoch: 59, TrainLoss: 0.0418, TrainDice: 0.0000, ValLoss: 0.0566
# Number of batches:  26
# [Training] Epoch: 60 [DONE]
# [Validation] Epoch: 60 [DONE]
# [Epoch: 60, TrainLoss: 0.0411, TrainDice: 0.0000, ValLoss: 0.0633
# Number of batches:  26
# [Training] Epoch: 61 [DONE]
# [Validation] Epoch: 61 [DONE]
# [Epoch: 61, TrainLoss: 0.0411, TrainDice: 0.0000, ValLoss: 0.0609
# Number of batches:  26
# [Training] Epoch: 62 [DONE]
# [Validation] Epoch: 62 [DONE]
# [Epoch: 62, TrainLoss: 0.0430, TrainDice: 0.0000, ValLoss: 0.0606
# Number of batches:  26
# [Training] Epoch: 63 [DONE]
# [Validation] Epoch: 63 [DONE]
# [Epoch: 63, TrainLoss: 0.0436, TrainDice: 0.0000, ValLoss: 0.0635
# Number of batches:  26
# [Training] Epoch: 64 [DONE]
# [Validation] Epoch: 64 [DONE]
# [Epoch: 64, TrainLoss: 0.0423, TrainDice: 0.0000, ValLoss: 0.0482
# Number of batches:  26
# [Training] Epoch: 65 [DONE]
# [Validation] Epoch: 65 [DONE]
# [Epoch: 65, TrainLoss: 0.0418, TrainDice: 0.0000, ValLoss: 0.0713
# Number of batches:  26
# [Training] Epoch: 66 [DONE]
# [Validation] Epoch: 66 [DONE]
# [Epoch: 66, TrainLoss: 0.0417, TrainDice: 0.0000, ValLoss: 0.0544
# Number of batches:  26
# [Training] Epoch: 67 [DONE]
# [Validation] Epoch: 67 [DONE]
# [Epoch: 67, TrainLoss: 0.0428, TrainDice: 0.0000, ValLoss: 0.0514
# Number of batches:  26
# [Training] Epoch: 68 [DONE]
# [Validation] Epoch: 68 [DONE]
# [Epoch: 68, TrainLoss: 0.0411, TrainDice: 0.0000, ValLoss: 0.0548
# Number of batches:  26
# [Training] Epoch: 69 [DONE]
# [Validation] Epoch: 69 [DONE]
# [Epoch: 69, TrainLoss: 0.0412, TrainDice: 0.0000, ValLoss: 0.0727
# Number of batches:  26
# [Training] Epoch: 70 [DONE]
# [Validation] Epoch: 70 [DONE]
# [Epoch: 70, TrainLoss: 0.0412, TrainDice: 0.0000, ValLoss: 0.0611
# Number of batches:  26
# [Training] Epoch: 71 [DONE]
# [Validation] Epoch: 71 [DONE]
# [Epoch: 71, TrainLoss: 0.0415, TrainDice: 0.0000, ValLoss: 0.0670
# Number of batches:  26
# [Training] Epoch: 72 [DONE]
# [Validation] Epoch: 72 [DONE]
# [Epoch: 72, TrainLoss: 0.0414, TrainDice: 0.0000, ValLoss: 0.0515
# Number of batches:  26
# [Training] Epoch: 73 [DONE]
# [Validation] Epoch: 73 [DONE]
# [Epoch: 73, TrainLoss: 0.0409, TrainDice: 0.0000, ValLoss: 0.0471
# Number of batches:  26
# [Training] Epoch: 74 [DONE]
# [Validation] Epoch: 74 [DONE]
# [Epoch: 74, TrainLoss: 0.0409, TrainDice: 0.0000, ValLoss: 0.0722
# Number of batches:  26
# [Training] Epoch: 75 [DONE]
# [Validation] Epoch: 75 [DONE]
# [Epoch: 75, TrainLoss: 0.0407, TrainDice: 0.0000, ValLoss: 0.0476
# Number of batches:  26
# [Training] Epoch: 76 [DONE]
# [Validation] Epoch: 76 [DONE]
# [Epoch: 76, TrainLoss: 0.0401, TrainDice: 0.0000, ValLoss: 0.0743
# Number of batches:  26
# [Training] Epoch: 77 [DONE]
# [Validation] Epoch: 77 [DONE]
# [Epoch: 77, TrainLoss: 0.0403, TrainDice: 0.0000, ValLoss: 0.0598
# Number of batches:  26
# [Training] Epoch: 78 [DONE]
# [Validation] Epoch: 78 [DONE]
# [Epoch: 78, TrainLoss: 0.0396, TrainDice: 0.0000, ValLoss: 0.0569
# Number of batches:  26
# [Training] Epoch: 79 [DONE]
# [Validation] Epoch: 79 [DONE]
# [Epoch: 79, TrainLoss: 0.0414, TrainDice: 0.0000, ValLoss: 0.0482
# Number of batches:  26
# [Training] Epoch: 80 [DONE]
# [Validation] Epoch: 80 [DONE]
# [Epoch: 80, TrainLoss: 0.0400, TrainDice: 0.0000, ValLoss: 0.0593
# Number of batches:  26
# [Training] Epoch: 81 [DONE]
# [Validation] Epoch: 81 [DONE]
# [Epoch: 81, TrainLoss: 0.0399, TrainDice: 0.0000, ValLoss: 0.0673
# Number of batches:  26
# [Training] Epoch: 82 [DONE]
# [Validation] Epoch: 82 [DONE]
# [Epoch: 82, TrainLoss: 0.0396, TrainDice: 0.0000, ValLoss: 0.0781
# Number of batches:  26
# [Training] Epoch: 83 [DONE]
# [Validation] Epoch: 83 [DONE]
# [Epoch: 83, TrainLoss: 0.0390, TrainDice: 0.0000, ValLoss: 0.0545
# Number of batches:  26
# [Training] Epoch: 84 [DONE]
# [Validation] Epoch: 84 [DONE]
# [Epoch: 84, TrainLoss: 0.0392, TrainDice: 0.0000, ValLoss: 0.0486
# Number of batches:  26
# [Training] Epoch: 85 [DONE]
# [Validation] Epoch: 85 [DONE]
# [Epoch: 85, TrainLoss: 0.0409, TrainDice: 0.0000, ValLoss: 0.0493
# Number of batches:  26
# [Training] Epoch: 86 [DONE]
# [Validation] Epoch: 86 [DONE]
# [Epoch: 86, TrainLoss: 0.0396, TrainDice: 0.0000, ValLoss: 0.0646
# Number of batches:  26
# [Training] Epoch: 87 [DONE]
# [Validation] Epoch: 87 [DONE]
# [Epoch: 87, TrainLoss: 0.0411, TrainDice: 0.0000, ValLoss: 0.0496
# Number of batches:  26
# [Training] Epoch: 88 [DONE]
# [Validation] Epoch: 88 [DONE]
# [Epoch: 88, TrainLoss: 0.0401, TrainDice: 0.0000, ValLoss: 0.0500
# Number of batches:  26
# [Training] Epoch: 89 [DONE]
# [Validation] Epoch: 89 [DONE]
# [Epoch: 89, TrainLoss: 0.0399, TrainDice: 0.0000, ValLoss: 0.0606
# Number of batches:  26
# [Training] Epoch: 90 [DONE]
# [Validation] Epoch: 90 [DONE]
# [Epoch: 90, TrainLoss: 0.0414, TrainDice: 0.0000, ValLoss: 0.0566
# Number of batches:  26
# [Training] Epoch: 91 [DONE]
# [Validation] Epoch: 91 [DONE]
# [Epoch: 91, TrainLoss: 0.0398, TrainDice: 0.0000, ValLoss: 0.0579
# Number of batches:  26
# [Training] Epoch: 92 [DONE]
# [Validation] Epoch: 92 [DONE]
# [Epoch: 92, TrainLoss: 0.0392, TrainDice: 0.0000, ValLoss: 0.0477
# Number of batches:  26
# [Training] Epoch: 93 [DONE]
# [Validation] Epoch: 93 [DONE]
# [Epoch: 93, TrainLoss: 0.0389, TrainDice: 0.0000, ValLoss: 0.0722
# Number of batches:  26
# [Training] Epoch: 94 [DONE]
# [Validation] Epoch: 94 [DONE]
# [Epoch: 94, TrainLoss: 0.0380, TrainDice: 0.0000, ValLoss: 0.0539
# Number of batches:  26
# [Training] Epoch: 95 [DONE]
# [Validation] Epoch: 95 [DONE]
# [Epoch: 95, TrainLoss: 0.0386, TrainDice: 0.0000, ValLoss: 0.0785
# Number of batches:  26
# [Training] Epoch: 96 [DONE]
# [Validation] Epoch: 96 [DONE]
# [Epoch: 96, TrainLoss: 0.0379, TrainDice: 0.0000, ValLoss: 0.0540
# Number of batches:  26
# [Training] Epoch: 97 [DONE]
# [Validation] Epoch: 97 [DONE]
# [Epoch: 97, TrainLoss: 0.0378, TrainDice: 0.0000, ValLoss: 0.0513
# Number of batches:  26
# [Training] Epoch: 98 [DONE]
# [Validation] Epoch: 98 [DONE]
# [Epoch: 98, TrainLoss: 0.0375, TrainDice: 0.0000, ValLoss: 0.0603
# Number of batches:  26
# [Training] Epoch: 99 [DONE]
# [Validation] Epoch: 99 [DONE]
# [Epoch: 99, TrainLoss: 0.0381, TrainDice: 0.0000, ValLoss: 0.0481
# Number of batches:  26
# [Training] Epoch: 100 [DONE]
# [Validation] Epoch: 100 [DONE]
# [Epoch: 100, TrainLoss: 0.0373, TrainDice: 0.0000, ValLoss: 0.0745
# Number of batches:  26
# [Training] Epoch: 101 [DONE]
# [Validation] Epoch: 101 [DONE]
# [Epoch: 101, TrainLoss: 0.0372, TrainDice: 0.0000, ValLoss: 0.0712
# Number of batches:  26
# [Training] Epoch: 102 [DONE]
# [Validation] Epoch: 102 [DONE]
# [Epoch: 102, TrainLoss: 0.0374, TrainDice: 0.0000, ValLoss: 0.0639
# Number of batches:  26
# [Training] Epoch: 103 [DONE]
# [Validation] Epoch: 103 [DONE]
# [Epoch: 103, TrainLoss: 0.0367, TrainDice: 0.0000, ValLoss: 0.0643
# Number of batches:  26
# [Training] Epoch: 104 [DONE]
# [Validation] Epoch: 104 [DONE]
# [Epoch: 104, TrainLoss: 0.0374, TrainDice: 0.0000, ValLoss: 0.0460
# Number of batches:  26
# [Training] Epoch: 105 [DONE]
# [Validation] Epoch: 105 [DONE]
# [Epoch: 105, TrainLoss: 0.0374, TrainDice: 0.0000, ValLoss: 0.0715
# Number of batches:  26
# [Training] Epoch: 106 [DONE]
# [Validation] Epoch: 106 [DONE]
# [Epoch: 106, TrainLoss: 0.0374, TrainDice: 0.0000, ValLoss: 0.0598
# Number of batches:  26
# [Training] Epoch: 107 [DONE]
# [Validation] Epoch: 107 [DONE]
# [Epoch: 107, TrainLoss: 0.0364, TrainDice: 0.0000, ValLoss: 0.0767
# Number of batches:  26
# [Training] Epoch: 108 [DONE]
# [Validation] Epoch: 108 [DONE]
# [Epoch: 108, TrainLoss: 0.0365, TrainDice: 0.0000, ValLoss: 0.0518
# Number of batches:  26
# [Training] Epoch: 109 [DONE]
# [Validation] Epoch: 109 [DONE]
# [Epoch: 109, TrainLoss: 0.0379, TrainDice: 0.0000, ValLoss: 0.0790
# Number of batches:  26
# [Training] Epoch: 110 [DONE]
# [Validation] Epoch: 110 [DONE]
# [Epoch: 110, TrainLoss: 0.0375, TrainDice: 0.0000, ValLoss: 0.0497
# Number of batches:  26
# [Training] Epoch: 111 [DONE]
# [Validation] Epoch: 111 [DONE]
# [Epoch: 111, TrainLoss: 0.0369, TrainDice: 0.0000, ValLoss: 0.0750
# Number of batches:  26
# [Training] Epoch: 112 [DONE]
# [Validation] Epoch: 112 [DONE]
# [Epoch: 112, TrainLoss: 0.0364, TrainDice: 0.0000, ValLoss: 0.0457
# Number of batches:  26
# [Training] Epoch: 113 [DONE]
# [Validation] Epoch: 113 [DONE]
# [Epoch: 113, TrainLoss: 0.0368, TrainDice: 0.0000, ValLoss: 0.0678
# Number of batches:  26
# [Training] Epoch: 114 [DONE]
# [Validation] Epoch: 114 [DONE]
# [Epoch: 114, TrainLoss: 0.0367, TrainDice: 0.0000, ValLoss: 0.0444
# Number of batches:  26
# [Training] Epoch: 115 [DONE]
# [Validation] Epoch: 115 [DONE]
# [Epoch: 115, TrainLoss: 0.0366, TrainDice: 0.0000, ValLoss: 0.0709
# Number of batches:  26
# [Training] Epoch: 116 [DONE]
# [Validation] Epoch: 116 [DONE]
# [Epoch: 116, TrainLoss: 0.0365, TrainDice: 0.0000, ValLoss: 0.0474
# Number of batches:  26
# [Training] Epoch: 117 [DONE]
# [Validation] Epoch: 117 [DONE]
# [Epoch: 117, TrainLoss: 0.0361, TrainDice: 0.0000, ValLoss: 0.0749
# Number of batches:  26
# [Training] Epoch: 118 [DONE]
# [Validation] Epoch: 118 [DONE]
# [Epoch: 118, TrainLoss: 0.0367, TrainDice: 0.0000, ValLoss: 0.0559
# Number of batches:  26
# [Training] Epoch: 119 [DONE]
# [Validation] Epoch: 119 [DONE]
# [Epoch: 119, TrainLoss: 0.0362, TrainDice: 0.0000, ValLoss: 0.0528
